# %%
! pip install urllib2
# Out:
# ...
#   Could not find a version that satisfies the requirement urllib2 (from versions: )
# No matching distribution found for urllib2

# %%
from bs4 import BeautifulSoup
import urllib.request as urllib2
import re
import csv
import numpy
 
html_page = urllib2.urlopen("https://indeed.com/cmp/_/job?jk=d191890436f86f39&tk=1d334tta4as0h800&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXafBY-B_ZA0H7QK4wIkf4Zizq9LqZLE7OdXT8830XJxRUAupCE5QudCrTnHdyeITf2B9zfUPEh2DO6J6a1HiXvfe_VGVxn_yJ7GNvqehX-mrK2HAYceXoBX6e12m0sdX6FbRh-p1fqj3bBvAEhOwVDrgIFQTtUmEJ42fsl7cvtVEQixBNJ-BsKSFkHHt-OnovvPtCtzCChJ9rz0SVlH0zC_unM70XUxvR5JXEbeIZCZn_7gdJMEFGAw_DRFSsa0ohyFMnQ1K1T0qLl-1cNZiK6fkfBS1lWhxS5gUj1GUsSNXiXGATfMUaM2mQJtFe6GJp746dYu_BIGl40w2NxVl6CRfHsqgvYpqQzeIRiBs0t5Nxxni64Vcy2sY-knr3TPZKXzcQznTVrnIXowQ7WOjdRJkFoE0YpRDyjg0GatDeEUQS_Ru4fLEKBw-DVyego73UakYV-o2ure9Y96x4d95Pc2CKK626Cm35WYZ9JFlpciDnwDBujTcV9t3ZRhjK8lw0wg")

soup = BeautifulSoup(html_page)
table = soup.find('table', 'JobListTable')
links = []
for link in table.findAll('a', attrs={'href': re.compile("/ShowJob")}):
    links.append(link.get('href'))
    
s = "https://www.schwabjobs.com/" + links[1]
print(s)
posting = urllib2.urlopen("https://www.schwabjobs.com/ShowJob/Id/1844187/Third-Party-Risk-Operations--Senior-Team-Manager/")

soup2 =  BeautifulSoup(posting)

value = soup2.findAll("div", {"class": "desc"})

enc = 'utf-8'
with open('freq.csv', 'r', encoding = enc) as f:
    reader = csv.reader(f)
    keywords = list(reader)
arr = [i[0] for i in keywords]

for val in value:
    st = val.text.split()
    for word in st:
        if(word in arr):
            print(word)
# Out:
# https://www.schwabjobs.com//ShowJob/Id/1941985/Associate-Financial-Consultant-Morristown,-NJ/
# investing
# people
# create
# driven
# purpose
# respect
# communities
# challenge
# create
# firm
# bring
# life
# employee
# guide
# invest
# adaptable
# people
# desire
# help
# clients
# established
# years
# ago
# help
# work
# investing
# accessible
# enter
# innovative
# driven
# people
# help
# create
# better
# responsible
# implementing
# relationship
# management
# process
# maximize
# performance
# assists
# meeting
# regulatory
# compliance
# responsible
# reporting
# contracts
# well
# creating
# records
# systems
# key
# member
# administration
# contract
# including
# contact
# individual
# role
# expectation
# responsibilities
# limited
# processing
# records
# update
# existing
# accurate
# provided
# compliance
# understanding
# contract
# ability
# high
# requirements
# develop
# processes
# special
# projects
# responsibilities
# years
# experience
# working
# focus
# ...

# %%
! pip install numpy

# %%
from bs4 import BeautifulSoup
import urllib.request as urllib2
import re
import csv
import numpy
 
html_page = urllib2.urlopen("https://www.indeed.com/cmp/Pnc-Financial-Services-Group/jobs?clearPrefilter=1#cmp-menu-container")
soup = BeautifulSoup(html_page,"html.parser")


links = soup.findAll('div',{'class': 'cmp-section cmp-with-border'})
for page in links:
    linkTags = page.find_all('a', attrs={'href': re.compile("/cmp")})
    for tag in linkTags:
        print(tag.get('href'))
# Out:
# /cmp/_/job?jk=e5f18d7e3d7dff18&tk=1d336ccah0kbu000
# /cmp/_/job?jk=1813ed38611df074&tk=1d336ccah0kbu000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6vxZlsYClqA2a8pSwxaDhLoVe0eeFTrvwmp3xKYvUy6EUyKySqcd8D8Yizt4XU333meAYOqD8eZ0BNvANSzZB7EHINgZw3nB9Fzw9D_a9IFDHmNfA-0rChP5kRSld1TjB2sGgVzoYZ0bouVOtoRZIDl_NyWqsM6YCu2OjBIAshvql0vcVyzfPLx_JLcHtJQ3GPI1O7JAGoNzeVj3Hb6orf2-tS7LVgLK_le7ghPFiOoBDbRGK-BrKQNe2zmKbp_rADWmUFIx1cfR_fkMdHaN6UpHQkRDgu-zZmzHU4_EB2H3XQmBPntgmZ7npDUssyI9UnqXESVWmbxTi6kzjcBIrJFkmtDK5CtvCUk4gCQKyvwH6O3ZLAoHsGlphDhFVzqlrnA2c88w7MgudTjwnFMy7oEy_gT7BTVE8fZHOslBbE5ESSNboonwlKJHrX_ySV00hddgt30Fr7O-6MLwHwjf8z2VGmNPACl62uwc5oapEGDL0LypO0p-GQqp_cFXLFaQ2Bm8xbIyWWPwN-sf33pYJ7w
# /cmp/_/job?jk=323c2accb8bb9c9e&tk=1d336ccah0kbu000
# /cmp/_/job?jk=bcdc83fa91ee3ead&tk=1d336ccah0kbu000
# /cmp/_/job?jk=18b31206fcb52d2d&tk=1d336ccah0kbu000
# /cmp/_/job?jk=593da1a235fba740&tk=1d336ccah0kbu000
# /cmp/_/job?jk=5f0e0ffe66f32922&tk=1d336ccah0kbu000
# ...

# %%
from bs4 import BeautifulSoup
import urllib.request as urllib2
import re
import csv
import numpy
 
html_page = urllib2.urlopen("https://www.indeed.com//cmp/_/job?jk=84803b57c0f25a6c&tk=1d336ccah0kbu000")
soup = BeautifulSoup(html_page,"html.parser")
print(soup)

links = soup.findAll('div',{'class': 'cmp-section cmp-with-border'})
for page in links:
    linkTags = page.find_all('a', attrs={'href': re.compile("/cmp")})
    for tag in linkTags:
        print(tag.get('href'))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-d5f5d63e8a15> in <module>
#       5 import numpy
#       6
# ----> 7 html_page = urllib2.urlopen("https://www.indeed.com//cmp/_/job?jk=84803b57c0f25a6c&tk=1d336ccah0kbu000")
#       8 soup = BeautifulSoup(html_page,"html.parser")
#       9 print(soup)
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ...
