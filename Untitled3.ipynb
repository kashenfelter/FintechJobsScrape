# %%
import string
import csv
import collections
import nltk
from nltk.corpus import stopwords
import operator
from collections import OrderedDict
import sys
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer.layout import LAParams
import io
import os
import math
from textblob import TextBlob as tb
import textrank

english_stops = []


def clean_tokens(tokens):
    """ Lowercases, takes out punct and stopwords and short strings """
    return [token.lower() for token in tokens if (token not in string.punctuation) and
               	(token.lower() not in english_stops) and len(token) > 2]

def get_stopwords():
    enc = 'utf-8'
    with open('stopword_file.csv', 'r', encoding = enc) as f:
        reader = csv.reader(f)
        keywords = list(reader)
    english_stops = [i[0] for i in keywords]
    #print ( english_stops)
    lemmatizer = nltk.stem.WordNetLemmatizer()
    
def get_cleanTokens(directory):
    cleanTokens = []
    wordcount = {} 
    for filename in os.listdir(directory):
        text = get_text("KeywordDocs/" + filename)
        tokens = nltk.word_tokenize(text)
        cleanTokens.extend(clean_tokens(tokens))
    return cleanTokens
     
def create_freqList(cleanTokens):
    for tok in cleanTokens:
        if tok not in wordcount:
            wordcount[tok] = 1
        else:
            wordcount[tok] += 1
        
    sorted_wordCount = OrderedDict(sorted(wordcount.items(), key=operator.itemgetter(1), reverse=True))
    write_csv(sorted_wordCount)

def write_csv(sorted_wordCount):
    enc = 'utf-8'
    if not os.path.isfile('frequency.csv'):
        with open('frequency.csv', 'w', encoding = enc) as f:
            for key in sorted_wordCount.keys():
                f.write("%s,\n"%(key))
    else:
        with open('frequency.csv', 'a+', encoding = enc) as f:
            for key in sorted_wordCount.keys():
                f.write("%s,\n"%(key))


def get_text(filename):
    fp = open(filename, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data =  retstr.getvalue()
    return data



def tf(word, blob):
    return (float)(blob.words.count(word)) / (float)(len(blob.words))

def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob)

def idf(word, bloblist): return math.log(len(bloblist) / (float)(1 + n_containing(word, bloblist)))

def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)


def create_tfIdfList(document):
    totalLength, splitLength = len(document), int(len(document)/400)
    bloblist = [ document[i:i+splitLength] for i in range(0, totalLength, splitLength) ]
    for i, blob in enumerate(bloblist):
        blob = tb(blob)
        scores = {word: tfidf(word, blob, bloblist) for word in blob.words}
        sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        enc = 'utf-8'
        with open('frequency.csv', 'a+', encoding = enc) as f:
            columnTitleRow = "Word, Score\n"
            f.write(columnTitleRow)
            for word, score in sorted_words: 
                score = "{},{}\n".format(word, round(score, 5))
                f.write(score)

def create_textrankList(sample_text):
    textrank_results = textrank.extractKeyphrases(sample_text)
    print(textrank_results)
    #for res in enumerate(textrank_results):
        #print(res)
        #break
        #with open('textrank.csv', 'a+', encoding = 'utf-8') as f:
            #for word in res:
                #f.write(word + ', ')




if __name__ == '__main__':
    get_stopwords()
    clean_tokens = get_cleanTokens("KeywordDocs")
    clean_doc = ' '.join(clean_tokens)
    #create_freqList(clean_tokens)
    #create_tfIdfList(' '.join(clean_tokens))
    parts = [ clean_doc[i:i+int(len(clean_doc)/10)] for i in range(0, len(clean_doc), int(len(clean_doc)/10)) ]
    for i,p in enumerate(parts):
        create_textrankList(p)
# Out:
# {'technical talent', 'material warrant', 'ability engage', 'evidence security', 'manage use', 'section sector', 'faster payment', 'sheet munich', 'different adoption', 'close‐to processing', 'local payment', 'local bank', 'experience pure', 'vulnerable disruption', 'disruption occur', 'payment profitability', 'large tech', 'develop new', 'stripe expand', 'next example', 'traditional ecosystem', 'race become', 'point sale', 'dominant online', 'quantitative evidence', 'decline product', 'transaction landscape', 'advisory', 'create personalized', 'fintech key', 'fund david', 'significant improvement', 'customer data', 'improvement new', 'internal', 'launch apple', 'online continue', 'relative importance', 'general information', 'low possible', 'driver introduction', 'creation new', 'competitive landscape', 'revised payment', 'chain pressure', 'purchasing behaviour', 'access example', 'enter new', 'potential systemic', 'debit', 'evidence level', 'incumbent credit‐card‐', 'erosion', 'limited incumbent', 'shopping key', 'first national', 'entrenched online', 'extent', 'creation different', 'insurance product', 'contact jesse', 'development new', 'geography', 'open secure', 'channel platform', 'infrastructure scale', 'vision', 'set large', 'march april', 'life', 'ecosystem critical', 'proposition traditional', 'position', 'opportunity', 'deep dive', 'new product', 'evolution credit', 'customer choice', 'distribution financial', 'technology governance', 'environment regional', 'become capable', 'industry‐standard automation', 'method payment', 'pragmatic assessment', 'justin pinkham', 'card issuing', 'business financial', 'transferwise retail', 'ecosystem description', 'structural transformation', 'such loan', 'industrial revolution', 'forum lead', 'comfortable', 'insurance value', 'arrival new', 'payment service', 'subsequent demand', 'product suitability', 'introduction', 'pivotal', 'lending sector', 'only improve', 'customer demand', 'uncertain', 'path', 'result adoption', 'responsible', 'improved price', 'traditional regulatory', 'cycle financial', 'ach network', 'new customer', 'baer huw', 'income', 'product manufacturing', 'offer tracking', 'top traditional', 'face competition', 'guidance oversight', 'recent', 'group head', 'key issue', 'europe other', 'purchasing insurance', 'evidence gradual', 'overwhelming dominance', 'robert palatnick', 'max neukirchen', 'customer info', 'vice‐president fintech', 'final phase', 'enough training', 'predominant payment', 'china online', 'evidence interchange', 'culmination', 'continued absence', 'role online', 'alternative payment', 'sharing economy6', 'commoditized context', 'need occur', 'santander neil', 'innovation financial', 'chief financial', 'incumbent service', 'ubiquity technology', 'dominance online', 'deloitte rgalaski', 'demise apple', 'amazon one‐click', 'end state', 'flint kimberly', 'due lack', 'basis', 'address open', 'critical successful', 'industry', 'continue move', 'cater specific', 'become difficult', 'financial system', 'security key', 'best‐of‐brand', 'new solution', 'info such', 'cash', 'merchant bank', 'extensive outreach', 'absence additional', 'policy size', 'application', 'range', 'major source', 'risk underwriters/product', 'usage apple', 'patient mentorship', 'future disruption', 'bank julius', 'customized payment', 'certain', 'decade', 'growth non‐catastrophe', 'david puth', 'rate cagr', 'mastercard rangaswami', 'compete', 'high‐value', 'payment apps', 'pool potential', 'own', 'competitive introduction', 'non‐existent introduction', 'total', 'foreword consistent', 'customer spending', 'sku‐level data', 'lack information', 'piece', 'kyc utility', 'innovative new', 'build', 'example automation', 'victor matarranz', 'rise customer', 'credit card', 'low usage', 'payment experience', 'merchant/intermediary level', 'customer adoption', 'acceptance nontraditional', 'information officer', 'europe psd2', 'redistribution profit', 'become key', 'example ayasdi', 'informati ...
# {'competitor offering', 'bank launch', 'course circa', 'legacy system', 'access new', 'mobile data', 'lack credit', 'offering digital', 'banking model', 'seek purchase', 'emergence banking', 'bike phone', 'loan tradeshift', 'banking industry', 'cusp significant', 'credit following', 'product open', 'many in‐house', 'game changer', 'offer term', 'disruption occur', 'flexible consumable', 'such direct', 'shift rigid', 'large tech', 'purchase term', 'develop new', 'technology enable', 'point sale', 'communication', 'face margin', 'mini bank', 'point distribution', 'underwriting technology', 'advanced', 'customer data', 'fixed‐time basis', 'connected', 'customer stickiness', 'development insurance', 'regulatory pressure', 'gap', 'competitive landscape', 'remain trustworthy', 'flexible product', 'onerous application', 'eventual modernization', 'enforced introduction', 'home purchase', 'create distribution', 'billion‐loan‐buying‐dealwith‐investors‐including‐soros‐jefferies‐1488222470 sofi', 'regulatory scrutiny', 'sustainability continued', 'noticeable share', 'operating expensive', 'intense regulatory', 'grow popularity', 'offer different', 'banking business', 'underbanked thin‐file', 'medium‐sized', 'evidence joint', 'deploy low‐cost', 'branch set', 'brand image', 'fintechs use', 'future lending', 'term funding', 'top group', 'time‐flexible', 'high funding', 'ecosystem critical', 'credit continued', 'home safety', 'shift offering', 'offer trade', 'few technological', 'start cutting', 'market deloitte', 'customer choice', 'other', 'core competitive', 'distribution financial', 'industry offer', 'guy carpenter', 'platform new', 'new adjudication', 'granular data', 'concern regulation', 'santander branch', 'access banking', 'trade financing', 'first online', 'way offering', 'current', 'exclusive distribution', 'comfortable', 'insurance value', 'origination service', 'guidance financial', 'global rise', 'use partnerships', 'commercial', 'flexible coverage', 'responsible', 'improvement', 'lending relationship', 'market dominance', 'monitor new', 'product manufacturing', 'source cost', 'develop sophisticated', 'leading', 'face competition', 'non‐financial firm', 'value physical', 'update volume', 'stay safe', 'good', 'bank charter', 'valuable credit', 'bain company', 'emergence platform', 'oligopolistic distribution', 'loyalty product', 'main', 'tools,7 suite', 'focus single', 'developing world', 'alexa impact', 'expensive legacy', 'set customer', 'trusting digital', 'robo‐distribution', 'niche lending', 'following investment', 'provide exposure‐specific', 'occur new', 'industry cost', 'transferwise,1 offer', 'product‐level partnerships', 'non‐financial', 'capital city', 'success shift', 'end state', 'data strategy', 'product distributor', 'order compete', 'consumer data', 'need consider', 'lending experience', 'insider nerdwallet', 'tethered rise', 'range mobile', 'join tech', 'consistent funding', 'application', 'data measure', 'run insurance', 'management asset', 'european challenger', 'sell open', 'decade', 'average net', 'additional effort', 'data breach', 'significant number', 'evidence new', 'product‐specific insurance', 'compete', 'narrow range', 'bank platform', 'analyse borrower', 'evidence improved', 'significant growth', 'profitable customer', 'core banking', 'institution power', 'marketplace lending', 'own', 'underwrite', 'integration', 'agile alternative', 'data protection', 'first time', 'morgan', 'use apis', 'scale product', 'limited high', 'user‐centred digital', 'approval', 'build', 'white label', 'exclusive partnerships', 'robo‐branch guide', 'human interaction', 'diverging', 'apis introduction', 'spending9', 'insurer innovation', 'normalized basis', 'finding few', 'building client', 'incumbent financial', 'availability credit', 'insurance remain', 'need non‐financial', 'incumbent lender', 'shift digital', 'divergent', 'approach result', 'possible ease', 'meet', 'growth traditional', 'adopt insurance', 'combination des ...
# {'uncertainty differing', 'guarantor', 'become much', 'driving demand', 'industry net', 'amount effort', 'many smart', 'strong demand', 'otc asset', 'trading lock‐out', 'growth political', 'change order', 'cooperative', 'exhibit similar', 'disruption occur', 'bloomberg investopedia', 'post‐ trade', 'automation technology', 'quantitative evidence', 'market‐data‐cost‐becoming‐big‐issue‐2016‐10 euronext', 'advanced', 'norm much', 'customer data', 'platform engagement', 'individualized', 'digital investment', 'customer stickiness', 'relative importance', 'ecosystems embrace', 'mean consolidation', 'gap', 'scale invest', 'creation new', 'offering increased', 'faq angellist', 'profitability social', 'b2c channel', 'regionalization', 'synthesis decision‐', 'ability own', 'cost become', 'run introduction', 'regulator convergence', 'money online', 'natural standardization', 'realize return', 'early‐ stage', 'widespread political', 'use crowdfunding', 'private market', 'insurance product', 'low seed‐stage', 'approval trade', 'development new', 'flexible settlement', 'platforms gain', 'diligence social', 'stake trumid', 'jun‐17 external', 'focus', 'infrastructure drive', 'further introduction', 'providing additional', 'blockchain technology', 'crowdfunding compliance', 'schwab investopedia', 'avi goldfarb', 'role such', 'capital weak', 'cross‐platform interoperability', 'new asset', 'tool analyse', 'ecosystem continued', 'advice intermediary', 'economical access', 'trumid young', 'harsher', 'high early', 'infrastructure industry', 'wise', 'budget basis', 'limited ability', 'driving monoline', 'valuable input', 'crowdfunding overview', 'lead significant', 'dependent sell‐side', 'global regulatory', 'reduced ability', 'imperative role', 'introduction', 'new platforms', 'gain popularity', 'growing', 'discount brokerage', 'ecosystems new', 'such quantopian', 'deutsche börse', 'quality execution', 'responsible', 'platforms invest', 'improvement', 'new customer', 'manager flat‐fee', 'raton florida', 'product manufacturing', 'flat‐fee digital', 'jurisdiction invest', 'leading', 'current practice', 'allocate high‐risk', 'improved investor', 'support introduction', 'regulatory treatment', 'network individual', 'outsized role', 'platform universe', 'deloitte casey', 'role future', 'regulatory path', 'major company', 'main', 'necessary cooperation', 'electronification asset', 'china current', 'post‐trade value', 'view relevant', 'institution ability', 'product selection', 'agrawal christian', 'smart oracle', 'robo‐distribution', 'year‐end', 'seed capital', 'technology offer', 'economic area', 'active', 'power', 'identify', 'altfi data', 'blockchain financial', 'commercial due', 'attractive source', 'occur new', 'technology revenue', 'discovery post‐trade', 'end state', 'success debt', 'represent ideal', 'engagement continued', 'inter‐platform connectivity', 'rise data', 'financial system', 'quality start‐ups', 'industry social', 'first regulated', 'predictable', 'use low‐cost', 'scale equity', 'invest alongside', 'wire altfi', 'point interaction', 'average fee', 'settlement allow', 'certain', 'decade', 'market launch', 'enhanced data', 'crowdfunding end', 'launched fintechs', 'offer third‐country', 'evidence new', 'compete', 'pre‐', 'expansion joint', 'further consolidation', 'accurate regulation', 'pool potential', 'core banking', 'own', 'margin compression', 'mean small', 'first time', 'insider introduction', 'lead seed', 'scale product', 'create standardized', 'fintechs gain', 'externalization efficient', 'equivalence transparency', 'innovative new', 'build', 'allow infrastructure', 'deal size', 'management exhibit', 'access capital', 'platform financial', 'new ecosystems', 'externalization', 'advice platform', 'brewery brewdog', 'exact impact', 'market trading', 'mass mass‐affluent', 'labor fiduciary', 'intuitive trading', 'weak critical', 'vanguard', 'scale buy‐side', 'convenient trade', 'post‐trade processing', 'secretary acosta', 'automate a ...
# {'identity transaction', 'consultant deloitte', 'deloitte greenhouse', 'america/merrill edge', 'internal system', 'amount information', 'development world', 'identity critical', 'therefore trusted', 'underserved', 'goldstein kellie', 'nature identity', 'scopelliti amy', 'karl sponholz', 'adizah tejani', 'topic identity', 'provide flexible', 'point view', 'desktop system', 'capital otkritie', 'luxembourg', 'levin evp', 'lendup colliderx', 'order paul', 'kim dan', 'legal record', 'information remediation', 'judicial administration', 'concierge digital', 'john clippinger', 'lab ledger', 'laurence latimer', 'sean kevelighan', 'online individual', 'risk interception', 'customer data', 'siddharth singh', 'distributed identity', 'tala citi', 'bankid public‐private', 'general information', 'mary‐catherine lader', 'third', 'skinner gordon', 'vandenreydt head', 'identity collection', 'unable', 'information revenue', 'service key', 'bouchard andre', 'open identity', 'llp compareasiagroup', 'peter berg', 'von arnim', 'improved compliance', 'complete certain', 'delivery improved', 'chase christine', 'financial history', 'project advisor', 'affiliation industry', 'able access', 'llc bank', 'contact jesse', 'smith mike', 'mastercard deloitte', 'stalnaker matthew', 'development new', 'landscape identity', 'strict regulation', 'ladder zestfinance', 'strategic product', 'illicit activity', 'hsbc school', 'implementation identity', 'extensive incremental', 'many anti‐fraud', 'attribute presentation', 'blockchain technology', 'garri', 'identity documentation', 'neil mumm', 'faiza harji', 'deloitte tax', 'closed system', 'asset rehypothecation', 'philipp kroemer', 'monlleo rasmus', 'equitable bank', 'obscure risk', 'control access', 'identity industry', 'user privacy', 'office australia', 'healthcare data', 'discrete', 'fundamental concept', 'bank america/merrill', 'uptake', 'hussain marta', 'party adoption', 'level39', 'patwardhan chief', 'identity management', 'börse paynearme', 'colm lyon', 'justin pinkham', 'business financial', 'due overexposure', 'swift ubs', 'david brewer', 'common… hack', 'management february', 'shah deloitte', 'reputational damage', 'process', 'external use', 'next section', 'relevance digital', 'centralized registry', 'flexibility physical', 'collection processes', 'gheel geert', 'introduction', 'electronifie jpmorgan', 'discuss technology', 'proof knowledge', 'non‐traditional', 'locke joseph', 'yankiver jason', 'nguyen trieu', 'integration transaction', 'brouwer ryan', 'tom hutton', 'age security', 'otterson robert', 'collection standard', 'deutsche börse', 'guardian april', 'complete identity', 'responsible', 'bergh micai', 'siroya travis', 'such address', 'cost avoidance…', 'baer huw', 'kamalia richard', 'verify programme', 'lamaud joel', 'connect many', 'drinking age', 'ach information', 'guidance oversight', 'hsbc kim', 'aig ubs', 'commerzbank digital', 'infrastructure', 'group head', 'crowded digital', 'white house', 'robert palatnick', 'such tax', 'max neukirchen', 'private provider', 'balderton capital', 'scott john', 'attestation', 'account etc', 'behalf key', 'view user', 'discuss', 'buying alcohol', 'pay fee', 'abel lee', 'purpose structure', 'innovation financial', 'kerrigan andrew', 'chief financial', 'gregory williamson', 'access online', 'provide security', 'john egan', 'deloitte rgalaski', 'vote users', 'michael drexler', 'trieu ramin', 'kantara initiative', 'birthdate transaction', 'sector private', 'hinrikus bianca', 'solution multi‐governmental', 'marta plana', 'bank daon', 'mcdonald morgan', 'provide standardized', 'ineffective know‐your‐customer', 'management system', 'richard kang', 'basis', 'users rps', 'user transacting', 'transact rps', 'finanser deloitte', 'identity proof', 'bowman eli', 'philippine electoral', 'effective identity', 'process inefficiency', 'transaction processes', 'set third‐party', 'example internal', 'improved knowledge', 'blueprint', 'melinda', 'organization purpose', 'bart b ...

# %%
! pip install textrank
# Out:
# Collecting textrank
#   Downloading https://files.pythonhosted.org/packages/99/bd/034ff58e00a6019dd45e3ffae865625da70b66e74151ea7e3b848ddd977d/textrank-0.1.0.tar.gz
# Building wheels for collected packages: textrank
#   Building wheel for textrank (setup.py): started
#   Building wheel for textrank (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\bhavy\AppData\Local\pip\Cache\wheels\64\25\bf\e1b2f46da8146fe46171099ac23f084c17b97c3088cf3f7065
# Successfully built textrank
# Installing collected packages: textrank
# Successfully installed textrank-0.1.0
