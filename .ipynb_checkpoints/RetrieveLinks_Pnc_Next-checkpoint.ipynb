# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib.request as urllib2
import re
import csv
import pandas as pd
import os
import numpy as np

bank = 'PNC Bank'
listId = 1
jobNo = 1
BASE = 'https://www.indeed.com/'
FIRST_LISTING_PAGE = 'https://www.indeed.com/cmp/Pnc-Financial-Services-Group/jobs?clearPrefilter=1'
LISTING_URL_PREFIX = 'https://www.indeed.com/cmp/Pnc-Financial-Services-Group/jobs?start='
LISTING_URL_POSTFIX = 'clearPrefilter=1#cmp-menu-container'

def keywordsFileName(listId):
    if listId == 1:
        return 'freq100.csv'
    elif listId == 2:
        return 'textRank.csv'
    else:
        return 'tfIdf.csv'

def scrape_site(Url):
    scrape_page(FIRST_LISTING_PAGE)
    for i in range(12,996,12):
        nextPageUrl = LISTING_URL_PREFIX +  str(i) + "&" + LISTING_URL_POSTFIX
        print("page - " + nextPageUrl)
        scrape_page(nextPageUrl)

def scrape_page(page):
    response = urlopen(page)
    bs_obj = BeautifulSoup(response, "html.parser")
    if bs_obj:
        links = bs_obj.findAll('div',{'class': 'cmp-section cmp-with-border'})
        for page in links:
            linkTags = page.find_all('a', attrs={'href': re.compile("/cmp/_")})
            for tag in linkTags:
                link = tag.get('href')
                postingUrl = BASE + link
                pageDict = scrape(postingUrl)
                if (type(pageDict) is dict):
                        data = pd.DataFrame([pageDict])
                        # if file does not exist write header 
                        if not os.path.isfile('pncData.csv'):
                            data.to_csv('pncData.csv', header='column_names')
                        else: 
                            # else it exists so append without writing the header
                            data.to_csv('pncData.csv', mode='a', header=False)
                else:
                    print("exception?")


def scrape(postingUrl):
    print("posting - " + postingUrl)
    global bank
    global listId
    global jobNo
    
    
    headers = ["Job No", "Institution", "List Id {1,2,3}", "URL (URL of the job posting)", "List id (1,2,3)"]
    values = [jobNo, bank, listId, postingUrl, listId]
    
    indices = list(range(1, 101))
    
    wordCountDict = dict.fromkeys(indices,0)
    postingDict = dict(zip(headers, values))
    
    enc = 'utf-8'
    with open(keywordsFileName(listId), 'r', encoding = enc) as f:
        reader = csv.reader(f)
        keywords = list(reader)
    arr = [i[0] for i in keywords]
    
    try:
        hdr = {'User-Agent': 'Mozilla/5.0'}
        request = urllib2.Request(postingUrl,headers=hdr)
        html_page = urlopen(request)
        soup2 =  BeautifulSoup(html_page,"html.parser")
        if bank == 'PNC Bank':
            value = soup2.find('input', {'id':'preLoadJSON'})
            for word in value.get('value').split('"CandLandPageText"')[1].replace("\\u003", " ").split():
                if(word in arr):
                    ind = arr.index(word)
                    wordCountDict[ind] = wordCountDict.get(ind, 0) + 1
            dataDict = postingDict.copy()  
            return {**postingDict, **wordCountDict}
                
        else:
            value = soup2.findAll("div", {"class": "desc"})
            for val in value:
                st = val.text.split()
                for word in st:
                    if(word in arr):
                        ind = arr.index(word)
                        wordCountDict[ind] = wordCountDict.get(ind, 0) + 1
    except:
        return ("An exception occurred")
    
    jobNo = jobNo + 1

    dataDict = postingDict.copy()  
    return {**postingDict, **wordCountDict} 



                
if __name__ == '__main__':
    scrape_site(LISTING_URL_PREFIX + LISTING_URL_POSTFIX)
# Out:
# posting - https://www.indeed.com//cmp/_/job?jk=f5df4ed098b9df5e&tk=1d377pq9f0mte000
# posting - https://www.indeed.com//cmp/_/job?jk=b9f01fc8684726f8&tk=1d377pq9f0mte000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXac_m9-fTbJh2bXSMOtpuQF9psoJiIjNq08-zXrPCp9FM-x_27b3HnDH3kNs38fcgo7XTM99d0lb97QbOjnG2zQZT1gtafDX3-7_8SZg4pqgnCvr4CAvSgfxF-_s72KkAPnRkb6DSF4Iu9IAY-YQOUfY4aKn6bIILXuQRxTGlXc5ykDuxuqLhXZKIdgdzLSShT0qXq12Lbb9LfJoWo61mT16WWS3kRC1AHGtGwfcQ761lNIhqzz1AccrBjANkh0pILbH1I-IefI5OEbnZgqy8YBzqRvgoaneqvf8IYYo4slXloReAr37VV_Oh2Kx1uUgZ93-yy0-czQz9sVZbH8ULCipPvsPIlv9uz8d34EpBlPP_rWFHM_cwD_wCgP57RMS7G7b5czY_eC4-G6bOKFbeMaSSsRl790JQHN9OJwNk4YCeSd9nXMhRkqEeqw2-wxVwWJLzhcFOtX1DbICsZZ1Sn2wdyo1nhwIyIdYM3SGo2qzri__NoXgoNaPM-YbAVpA-zU
# posting - https://www.indeed.com//cmp/_/job?jk=e5f18d7e3d7dff18&tk=1d377pq9f0mte000
# posting - https://www.indeed.com//cmp/_/job?jk=cebe7bb3c395094e&tk=1d377pq9f0mte000
# posting - https://www.indeed.com//cmp/_/job?jk=33f0ec32a7975057&tk=1d377pq9f0mte000
# posting - https://www.indeed.com//cmp/_/job?jk=db3e14139dec1768&tk=1d377pq9f0mte000
# posting - https://www.indeed.com//cmp/_/job?jk=da5c29db7ae61182&tk=1d377pq9f0mte000
# posting - https://www.indeed.com//cmp/_/job?jk=aa26c5e215f44029&tk=1d377pq9f0mte000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXaeF2VXMphbnQjA1XkSuHHDOUQfLvD9IQCWgu34OzYiH2VvcvWvoz0eAGHXuWc0TeikFFZPBRfFvdKgWknIQJrtn7laIoaHepz592LxXs4Fi6puW_cgWuOvA0uWWdv5IbHAqJ1a_Hf_DNUu6saHyDjcGPZn0Ep6J-LZguii6-bx9o4DXNdlECYUfWO7GVZifr55hL6h2CUt-WJQVeyknGNrdLPC6tSRJO0fw3KqJxQzvAgs4HSM4i1Inla5ey_gDPKIASJdv8lGxO9TCnAv77anf4m9nNWJKHE0XEsLgyKXqxmSeouy9xGEHlVJbfiwhDA70pgbci7Xk3lTwRVTO303CM7qJxZyrAP1yHLEzWNcQACd8wArV8DqesEJjR5KEuADZQkBkbQGm1UwyrQChjLKH15pe0hcNaE1DK7qyhohAfabzjfuMYTZZLrWtuIjQ3Rsxlvrd5Urp4LKjkAIqz_hqdyo1nhwIyIdYM3SGo2qzri__NoXgoNaPM-YbAVpA-zU
# posting - https://www.indeed.com//cmp/_/job?jk=d3db4e778cc5d7e4&tk=1d377pq9f0mte000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXaci5_bgry_Nc-M0lpsrZzPwg6jvDpO3rHmGtG8z0LGzhROBLke_CImQFxSzyYbVAryAy6YddEzt0lLnaLcmm2IcSelrIxSiROT7XS3sum1aLqE_87Z2mUnXdNOPqpjWvRsiE9sgNui8n4vUAxaeJRwnELBwMjnOsFXMIK9T4mleKbbHTlE82coQRPRiET4M8kIE83lC41GRuACiBOW66ujITutqqs2IbHNQ3lszLI8_tdVBlBRSd-UHm2TxveacSFA94mbdTyjiGY_FfeYAD8mA1oSqgW5_8VViC6vImgV3Nv8cpgxhWhXNam63gkH78n_qaBQD7Z2PMXook8YLWXjgUWOzTIvhoSbW_RX0L8qV0krf2yxkh1FY6eipxhjmiuDlZtaSXlfuXjCTIPVMadYPyPEQp2FmF85O5F9K-nti8mDf8ost4kT_G3l9aUvpPXVgHhB3ERz06k6vIgUW0swJdyo1nhwIyIdYM3SGo2qzri__NoXgoNaPM-YbAVpA-zU
# posting - https://www.indeed.com//cmp/_/job?jk=e0f344c0c94c4e45&tk=1d377pq9f0mte000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXadWSZf4zRfZrh_KklQt-1ZuOS7mi0NLjOUmxC-p-7V-6S88z9A5oNLzhLvcl4CoOMVluPahAC_Sulp1quWAxAd_LpgypTZ7VUT8qqWGvEEXCYsTyI07wL58bG8uV_n-RCI6VdXAXM7mzwdJWoYjnO3imlfURM9t9PLFWpAhPQximFMQupaoMWsrpSi_L-ngpedJV-HmwZVihtEMG3SraVjo48w7RNXSGMT9TC3eL_aQ5RokTIh5JmGwwdmKpDscV9PrPjrD1xcMpGx5irXR2mP5FOfwrBx8V1fbxZyAIC0-O5mnCBfqYdYasbXhL4Kx9MNzF-DLQmIaZFhgee7R42sfrDcFnHQW2wwALPA7GQaUpj4poFZ2shmm4IHZvKd58RSbapGYhayP1i0Zp3LwnyDykbDa4Ar6xJK_PFakmdVhj-SZxyQhfOHlkZ69Ii9_PaWBRz97z3mIoYw2zszSzn38dyo1nhwIyIdYM3SGo2qzri__NoXgoNaPM-YbAVpA-zU
# posting - https://www.indeed.com//cmp/_/job?jk=cf29d9833eb7e3e3&tk=1d377pq9f0mte000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXaeF2VXMphbnQjA1XkSuHHDOwtRUNFz3Qe4o7bfDcNeJ85eT8VrsL9Ig4FDGLC0RSU499-agY1P9rqEpzHiUN1cRM30BD538UHl_b4N6M4pvog16z5sAFbZ8nBFTLiH2vZlc2ptPNh6tT8LoJ-sSWpLY6usxdd0b2ydz5psbIVZSLJZAFovdf2XbcsLYAhMGiwAFrBnxLpzK5vQuLcbocCwPkAZwGgM82HXPimnXIp7HN4bhy40O3E1DoLTPZoc4MRzQF97l8rhpW16XLnA60IU0MMVWVyxcvPC1pboFWsiNgQFxEqjJDRXjhKO-8HkckztVLZBa457UNDn7Iq8gRSnTBlYzw8Jl1YgjC_YSnEZdfvzXZ9WMwKzOCepRYrZHo9WNb2VOvrXFWpsfnPGl09J5G61R38w73RSuaszdUQ7mjx22sKkjpzmjyoA-CFtx7sarmQv9ux0tvsbHKEku6EzRdyo1nhwIyIdYM3SGo2qzri__NoXgoNaPM-YbAVpA-zU
# posting - https://www.indeed.com//cmp/_/job?jk=a6938c6252492161&tk=1d377pq9f0mte000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXac0Oip-n9onAE0AxlFJVc4nYw8Zcw09lRovrfKgh5G6pd9aJNnmqzsvi8ZD9vBwZd9g533IvhPuekVFbewzobqTraF_0eF5_t3HWC9OkQsRxHCgVckZmZtKB3_Un6b_u-Ro-VIqwJcXcyT-9ZAkaqdg7Cx3uj_zIXI6Va8Gm8qTa80X5I9jMofAy7BcOW7g6knQ5ugEOUo5GfmnDe_8N84WK8TljKNH_xPMsr2YhmWmjg0nIKB-uVKoY3tsSzpOWK-PKNoieT0ASURav1NvQL7kqRqnK1oqPKYUcZ7JIJhWCqIUlnWLNNtX4Lvca1rf2iB_ap47LSyB8hm4j6SklJA4jHY91OuL8B9fOA_FXHwkEadSEw5PdVJM1LOZcRoylTfNWt0Mj26iQxyQPwKhYOqc0SDm9odf0669DJBhA7w0o0e56uYJwXNVhtxdsOZGAuF6pnFiCenMHYehZVlATEISdyo1nhwIyIdYM3SGo2qzri__NoXgoNaPM-YbAVpA-zU
# page - https://www.indeed.com/cmp/Pnc-Financial-Services-Group/jobs?start=12&clearPrefilter=1#cmp-menu-container
# posting - https://www.indeed.com//cmp/_/job?jk=a53c354dbfb1df18&tk=1d377qbli0kbu000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXaeF2VXMphbnQjA1XkSuHHDOuNSd22MH-dhy8mYFnqJYGOjxKgYhEPEk0nt_RLhrIuGBjd1tEliwZ-06_RcA5A7L5K6sR0tG70-ZbgvQVxVaaK2AHsevt_0TceMYNLcfi6CMT9x_Zc98WZbFq7zeCE2QFK-S89s81p_9PzFH_7_CVsM5QGhzUNr6ufIaamGS4FtiKJflG5sLoEwHAjUZVjmukDAaAZjFLta7X_GAKAkLA_kQb0D2SrhFxfHr8rV5yfwa1HnfnlkJtUkaxcVYp7Y41r6A2wAwYXb89mCtoumo4rLCfFFLrhc6ZU7oK9-qenNdfKr8Fqnf35YwvKgQcedDP_t2c_EAHKgk7z4rKFeWf3goPv32-43NieMMgSENPaFdrZRjZzD6HjjrdQDaYTvsWT8p7mQP0nhkdPSxio6xrWOU1rN1BdFWreXse_jnWh1AgxhmnqsfD9v61jVOptQ6P4JA1lDpjXXy4c3AO4tLaMxYvLWGUzc8eJ1AxYJ_TSQ
# exception?
# posting - https://www.indeed.com//cmp/_/job?jk=84f2181c3a489087&tk=1d377qbli0kbu000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXafYVAmw6fYA8PBBZzQ4-iYh5WnmkkFZMpGYDxJ3N-OXxdRJ6oJVqJ_7ynyyL-7798050UXaavD4F8emZ9sQuPse2XG8Z64XveKk2Yz2z-5LDiiev_PoPWZPoMo-bOQuP_inK9PxJC_quwis7zi0Vze51pYAC9DY78wKAhro5v1EQeNM1-dddQpeHSv4cdQNJtMeEEU-XULZNzS2s3yinvd7_eWrujvFOuKNpacR3-QLXxIqDrXiWRFVzlLXbzvee__ECzmwLcYHIDBBRPshaGargNv98nXq3AGI22LbIaIW8Rv21UPFrqLCh-Wu-F0hEHBeWWAtQdIcRTx3_Z8G_SOsTpMbQKO1s1Nq_x_phqQxLJnNGYBKsWkiUE5YH_wGgr5Vkg_gfUQtlV5R79AygMDuE9HUCF5ItbIAvqGhEaWxaDRCdeub-Cy2Z2BJugk1g6qqnNsb9XB-5GJmJp_hf92UP4JA1lDpjXXy4c3AO4tLaMxYvLWGUzc8eJ1AxYJ_TSQ
# posting - https://www.indeed.com//cmp/_/job?jk=9dd1fb92ae55b946&tk=1d377qbli0kbu000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXaeF2VXMphbnQjA1XkSuHHDOWhFxINTBSbzA15ZB8Oripo5qQUf6k4ufkCdzVws7d34ezRgoI_srCMlWukgmX-pWi6oD8PY6jIVurIbb4O85XBmn_1LRg3dKJ9rxVITjQYphc7JMGbbArFG5Rw03eKhII65gkSoKI7dJlQnRpFsNK5PyoaV5_GG6ELvJEiCWNoKWy_wOtVqn2ETYb8tIu703NL4tOa5lM4IWYbycnE04A2DzVKK2OFEcXxb0wWpcsy8gygSleM26cySpM4Zltq-LK4vwF6wkkNPL_A_aOsfv-eAqDOu5-g4cBjGTT0C7GheDxygA9VQ1AAfkjosawA6di79OE8eC-LitRcqrnCXMFXUKL1VtoQYXSnStZ6ob8xMMGCpp4zCb2VfBEWWqyTLo0As2PBFNPKlYypXXBf5yzgek_7QjF2cNvlFvNMWqhBMIC3ExL_fxv0kpEn4TWUuMP4JA1lDpjXXy4c3AO4tLaMxYvLWGUzc8eJ1AxYJ_TSQ
# posting - https://www.indeed.com//cmp/_/job?jk=3655e4a5a446c3ad&tk=1d377qbli0kbu000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXad1YFjfOuzdxNcSMnrB_Uy_Iz3SyVi3hnpubQ18DbY7Up08IvpzB_zYd-ucYbfJIXYQcDdM0XIp-QbF58ry9C4pVXnMeAkyL1w5tdPe8cgm9lS-CmXAL2Yeh_WNr9JChVbpoRRAy3fUYE3iXxxpeNy4gkeiDQY7-DTQUZ6s758h1i484SakMcr324KZAYrpxVbEmTAqYs1Cm6Y-qjzfx6QJ3qDyVmTXF96fv24CUWgwnjK0rVdrydhM_C29tIVp_uH1QFSvmVgXcCWh5V9urZ1LU1AZUaYJzsAR39UBrBlj6StyCXUCnDYQLiy4o5DMj5WfharU44AN9kl68nEr7SsSOIE6y6HrhHqzyCSblX9ERyy-8LI1YHvjUYihcOdVolaZd8CGNbqLx0MR2bnirk2yxFT8A9dkgCE6kkMG3ft0BQkxaMsf9SQ9JBZFds3_T7RVJ3m7S5DIBBV-Jpcz-eU_P4JA1lDpjXXy4c3AO4tLaMxYvLWGUzc8eJ1AxYJ_TSQ
# posting - https://www.indeed.com//cmp/_/job?jk=1a4114b8edfce613&tk=1d377qbli0kbu000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXadVS7g6esiocjY86qU_C9ZCSt6ZNBQSOvfYzhsPGpTGYvM7AkgkpBdunyIFKsqC_5MhVqO6ukvNSGWnDIubakg-d88chc3BRv9dph795MzBcGILK-Y9VN84mCma-buJpMXkXtPfovNdqw_xhlY1sajsHD6OazVoUPI5Tyzqv4vdrWDTF2inj0sodbhzKlTBmpgcZyxfxjMllc81Jr97HxaQvhcUQpCrIAf2Qvl8MaRF8oKfNF4r7vd-xKk7YZJrurVFoeyYrF-Gv-7aEj9pFmz0q23-HOH78in_Z1v0F8-pEOOBLGGyvOU_n2tu7GCq_fZ_5gX8q1Y6Tp-7dUmJHPoAn7Duxgof7q3yJAISsebDXW6UHdRoBBsLmVkmIM5j8ZOWyzmSzwdyAnx8fhZxTyXpZFMg1RYy3fs5BJI4HNKe6RItM1i-x3xHSZaALAPwl8e55i5nNxehiaDfXqSW0o2uP4JA1lDpjXXy4c3AO4tLaMxYvLWGUzc8eJ1AxYJ_TSQ
# posting - https://www.indeed.com//cmp/_/job?jk=91009db8062e49af&tk=1d377qbli0kbu000
# exception?
# posting - https://www.indeed.com//cmp/_/job?jk=c433caffcba1dda8&tk=1d377qbli0kbu000
# posting - https://www.indeed.com//cmp/_/job?jk=dcc68b57ce8b7d04&tk=1d377qbli0kbu000&rd=n5r6n1S2hixwO8gpEj_fuBcDY5Ws-Xs_yuMBKiKofo91uS6Q69ktC-y-BiMHNS3ifTU3X4Uxq_eODsJbhaKG6pWY1xKe9vZtztShvwGdXafHvj4YHgDfuyQkG2-OsXspIQosQO--77iLDs68YbplDcTiRj99J8MUYb1VEYmIOFuXvSgIBW9nVX21hnV2pdrY-qqw3_S1_bEcOs-5WNl9pmSoZrNT4hR6tDFKSbckkBc0Jr5q38H2vYSttPhRJpAloP2YfLPJGpJ--uGhRSdcTlxnpoJgTsqltGqBpYTB4AHx5Ijh1MiQlgCxXYYJWr464CwrAvxBJ5o3OBQkFTtINwVfV3PN8vRIIfOzr2rbSutfiSuIrlRXsFfPPZYkUsS67NlILGNupWW8Ec4ml2UpprXqjL2Idah176H9axrcYslWtcxdFeCRDIsWpDAMREtaMRMR9VPHinea_skPtPQR8QxYHuHamZXjT3gXNhHUDskWQ0Ukry2pQvM6KiwAfw9BbgFo04hDFp15FfdJ10ryumPKGcU3IJVS1hc2cBa8FyXSUtsVyzg5Nquyx36hawbyP4JA1lDpjXXy4c3AO4tLaMxYvLWGUzc8eJ1AxYJ_TSQ
