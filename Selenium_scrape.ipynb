# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common import action_chains, keys
import time
from bs4 import BeautifulSoup
import re
import os

#launch url
url = "https://sjobs.brassring.com/TGnewUI/Search/Home/Home?partnerid=15783&siteid=5130#home"

driver = webdriver.Chrome()
driver.implicitly_wait(50)
driver.get(url)

assert 'homeContainer' in driver.page_source
action = action_chains.ActionChains(driver)

# open up the developer console, mine on MAC, yours may be diff key combo
action.send_keys(keys.Keys.COMMAND+keys.Keys.ALT+'i')
action.perform()
time.sleep(3)
# this below ENTER is to rid of the above "i"
action.send_keys(keys.Keys.ENTER)
# inject the JavaScript...
action.send_keys("document.querySelectorAll('label.boxed')[1].click()"+keys.Keys.ENTER)
action.perform()


soup_level1=BeautifulSoup(driver.page_source, 'lxml')

links = soup_level1.find('a')
print(links)
# Out:
# <a after-toggle="handlers.trapHeaderLinkFocus" class="backLink" click-to-toggle="bPhoneViewLinksVisible" href="#0">Back</a>

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time, re, string

url = "https://sjobs.brassring.com/TGnewUI/Search/Home/Home?partnerid=15783&siteid=5130#keyWordSearch=&locationSearch="

driver = webdriver.Chrome()
driver.get(url)

time.sleep(5) #extra time to let all JS on site load

#returns site HTML and encodes to ascii for BeautifulSoup
html = (driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")).encode()

soup_level1=BeautifulSoup(html, 'lxml')


links = soup_level1.findAll('a')
for link in links:
    print(link)
# Out:
# b'<span class="ladda-label">Search</span><span class="ladda-spinner"></span>'

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time, re, string

url = "https://sjobs.brassring.com/TGnewUI/Search/Home/Home?partnerid=15783&siteid=5130#keyWordSearch=branch%20sales%20&%20service%20assistant%20manager%20(mlo)&locationSearch=New%20York,New%20York,United%20States"

driver = webdriver.Chrome()
driver.get(url)

time.sleep(5) #extra time to let all JS on site load

#returns site HTML and encodes to ascii for BeautifulSoup
html = (driver.execute_script("return document.getElementsByTagName('html')[0].innerHTML")).encode()
print(html)
soup_level1=BeautifulSoup(html, 'lxml')
# Out:
# b'<!--<![endif]--><head><style type="text/css">@charset "UTF-8";[ng\\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\\:form{display:block;}.ng-animate-block-transitions{transition:0s all!important;-webkit-transition:0s all!important;}</style>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta http-equiv="content-type" content="text/html; charset=UTF-8"><script type="text/javascript" src="https://bam.nr-data.net/1/0c4d2a794f?a=116819536&amp;v=1118.0c07c19&amp;to=ZwEHZUAECkQFWhFbVl5LKGdxSixYCVwmXVdEFgpdXgAWGCxWCFc%3D&amp;rst=3467&amp;ref=https://sjobs.brassring.com/TGnewUI/Search/Home/Home&amp;qt=1&amp;ap=260&amp;be=1011&amp;fe=3339&amp;dc=2367&amp;tt=4A88050BA16398BF&amp;af=err,xhr,stn,ins&amp;perf=%7B%22timing%22:%7B%22of%22:1549409812281,%22n%22:0,%22f%22:1,%22dn%22:2,%22dne%22:2,%22c%22:2,%22s%22:152,%22ce%22:462,%22rq%22:462,%22rp%22:854,%22rpe%22:1187,%22dl%22:860,%22di%22:2367,%22ds%22:2367,%22de%22:26
# ...

# %%
import bs4
import re
from time import sleep

sleep(1)
root=bs4.BeautifulSoup(innerHTML,"lxml")
viewcount=root.find_all("button",attrs={'class':'primaryButton ladda-button ng-binding'})


for span in viewcount:
    print(span)

button = driver.find_element_by_id("searchControls_BUTTON_2")
button.click()    
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-e4278696de45> in <module>
#       4
#       5 sleep(1)
# ----> 6 root=bs4.BeautifulSoup(innerHTML,"lxml")
#       7 viewcount=root.find_all("button",attrs={'class':'primaryButton ladda-button ng-binding'})
#       8
#
# NameError: name 'innerHTML' is not defined
