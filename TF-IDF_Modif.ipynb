# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import math

text1=""""
If you like pancakes combine it with maple syrup and whipped cream.
It's really not that bad as it sounds.
If the Easter bunny and the tooth fairy had babies would they take 
your teeth and laeve chocolate for you?
"""

def remove_string_special_character(s):
    stripped = re.sub('[^\w\s]', '', s)
    stripped = re.sub('-', '', stripped)
    
    stripped = re.sub('\s+', '', stripped)
    
    stripped = stripped.strip()
    
    return stripped

def get_doc(sent):
    doc_info = []
    i=0
    for sent in text_sents_clean:
        i += 1
        count = count_words(sent)
        temp = {'doc_id' : i,'doc_length' : count}
        doc_info.append(temp)
    return doc_info



def count_words(sent):
    count = 0
    words = word_tokenize(sent)
    for wor in words:
        count +=1
    return count



def create_freq_dict(sents):
    i = 0
    freqDict_list = [] 
    for sent in sents:
        i +=  1
        freq_dict = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
            if word in freq_dict:
                freq_dict[word] += 1
            else:
                freq_dict[word] = 1
            temp = {'doc_id' : i,'freq_dict' : freq_dict}
        freqDict_list.append(temp) 
    return freqDict_list   


def computeTF(doc_info,dreqDict_list):
    TF_scores = []
    for tempDict in freqDict_list:
        id = tempDict['doc_id']
        for k in tempDict['freq_dict']:
            temp = {'doc_id' : id,
                   'TF_score' : tempDict['freq_dict'][k]/doc_info[id-1]['doc_length'],'key' : k}
            TF_scores.append(temp)   
    return TF_scores       


def computeIDF(doc_info, freqDict_list):
    IDF_scores = []
    counter = 0
    for dict in freqDict_list:
        counter += 1
        for k in dict['freq_dict'].keys():
            count = sum([k in tempDict['freq_dict'] for tempDict in freqDict_list])
            temp = {'doc_id' : counter,'IDF_scores': math.log(len(doc_info)/count), 'key' : k}
            
            IDF_scores.append(temp)
            
    return IDF_scores   



def computeTFIDF(TF_scores,IDF_scores):
    TFIDF_scores = []
    for j in IDF_scores:
        for i in TF_scores:
            if j['key'] == i['key'] and j['doc_id'] == i['doc_id']:
                temp = {'doc_id' : j['doc_id'],
                       'TFIDF_score' : j['IDF_score']*i['TF_score'],
                       'key' : i['key']}
        TFIDF_scores.append(temp)
    return TFIDF_scores   

enc = 'utf-8'
file = open('filter.txt','r', encoding = enc)
text = file.read()

text_sents = sent_tokenize(text)
text_sents_clean = [remove_string_special_character(s) for s in text_sents]

doc_info = get_doc(text_sents_clean)

freqDict_list = create_freq_dict(text_sents_clean)
TF_scores = computeTF(doc_info,freqDict_list)
IDF_scores = computeIDF(doc_info,freqDict_list)
# Out:
# [{'doc_id': 1, 'IDF_scores': 6.75110146893676, 'key': ''}, {'doc_id': 2, 'IDF_scores': 6.75110146893676, 'key': 'theyincludedtheforumsfinancialservicesinnovationandtechnologycommunitiesprofessionalsfromacademiaandthepublicsector'}, {'doc_id': 3, 'IDF_scores': 6.75110146893676, 'key': 'theoutreachinvolvedover150interviewsand10internationalworkshopsessionsencouragingcollaborativedialoguetodiscussinsightsandopportunitiesconcerningfintechdisruptionwithinthefinancialservicesindustry'}, {'doc_id': 4, 'IDF_scores': 6.75110146893676, 'key': 'theholisticandglobalperspectiveofthisreportwouldnotbeasenrichedwithoutthesupportandcontributionsfromthesubjectmatterexpertswhoassistedindrivingourthoughtsforwardaboutthefutureofthefinancialservicesindustry'}, {'doc_id': 5, 'IDF_scores': 6.75110146893676, 'key': 'inparticularwethankthisprojectssteeringcommitteeandworkinggroupintroducedintheacknowledgementssectionwhichplayedaninvaluablerolewiththeirexpertiseandpatientmentorship'}, {'doc_id': 6, 'IDF_scores': 6.75110146893676, 'key': 'alsocriticalhasbeentheongoinginstitutionalsupportforthisinitiativefromtheforumandtheleadershipofourchairmanwhosevisionofthefourthindustrialrevolutionhasbeeninspirationaltothiswork'}, {'doc_id': 7, 'IDF_scores': 6.75110146893676, 'key': 'finallywearegratefultodeloitteconsultingllpintheunitedstatesanentitywithinthedeloitte1networkforitsgenerouscommitmentandsupportinitscapacityastheofficialprofessionalservicesadvisertotheforumforthisproject'}, {'doc_id': 8, 'IDF_scores': 6.75110146893676, 'key': ''}, {'doc_id': 9, 'IDF_scores': 6.75110146893676, 'key': 'dttlandeachofitsmemberfirmsarelegallyseparateandindependententities'}, {'doc_id': 10, 'IDF_scores': 6.75110146893676, 'key': 'dttlalsoreferredtoasdeloitteglobaldoesnotprovideservicestoclients'}, {'doc_id': 11, 'IDF_scores': 6.75110146893676, 'key': 'pleaseseewwwdeloittecomaboutforamoredetaileddescriptionofdttlanditsmemberfirms'}, {'doc_id': 12, 'IDF_scores': 6.75110146893676, 'key': 'pleaseseewwwdeloittecomusaboutforadetaileddescriptionofthelegalstructureofdeloittellpanditssubsidiaries'}, {'doc_id': 13, 'IDF_scores': 6.75110146893676, 'key': 'certainservicesmaynotbeavailabletoattestclientsundertherulesandregulationsofpublicaccounting'}, {'doc_id': 14, 'IDF_scores': 6.75110146893676, 'key': 'thispublicationcontainsgeneralinformationonlyanddeloitteisnotbymeansofthispublicationrenderingaccountingbusinessfinancialinvestmentlegaltaxorotherprofessionaladviceorservices'}, {'doc_id': 15, 'IDF_scores': 6.75110146893676, 'key': 'thispublicationisnotasubstituteforsuchprofessionaladviceorservicesnorshoulditbeusedasabasisforanydecisionoractionthatmayaffectyourbusiness'}, {'doc_id': 16, 'IDF_scores': 6.75110146893676, 'key': 'beforemakinganydecisionortakinganyactionthatmayaffectyourbusinessyoushouldconsultaqualifiedprofessionaladviser'}, {'doc_id': 17, 'IDF_scores': 6.75110146893676, 'key': 'deloitteshallnotberesponsibleforanylosssustainedbyanypersonwhoreliesonthispublication'}, {'doc_id': 18, 'IDF_scores': 6.75110146893676, 'key': '...'}, {'doc_id': 19, 'IDF_scores': 6.75110146893676, 'key': 'butinthewingsanewchallengeforthefinancialsystemwasgrowingintheformoffintechnewentrantsthatpromisedtorapidlyreshapehowfinancialproductswerestructuredprovisionedandconsumed'}, {'doc_id': 20, 'IDF_scores': 6.75110146893676, 'key': 'nearlyfouryearslaterasthisinitiativedrawstoa ...

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import math

text1=""""
If you like pancakes combine it with maple syrup and whipped cream.
It's really not that bad as it sounds.
If the Easter bunny and the tooth fairy had babies would they take 
your teeth and laeve chocolate for you?
"""

def remove_string_special_character(s):
    stripped = re.sub('[^\w\s]', '', s)
    stripped = re.sub('-', '', stripped)
    
    stripped = re.sub('\s+', '', stripped)
    
    stripped = stripped.strip()
    
    return stripped

def get_doc(sent):
    doc_info = []
    i=0
    for sent in text_sents_clean:
        i += 1
        count = count_words(sent)
        temp = {'doc_id' : i,'doc_length' : count}
        doc_info.append(temp)
    return doc_info



def count_words(sent):
    count = 0
    words = word_tokenize(sent)
    for wor in words:
        count +=1
    return count



def create_freq_dict(sents):
    i = 0
    freqDict_list = [] 
    for sent in sents:
        i +=  1
        freq_dict = {}
        words = word_tokenize(sent)
        for word in words:
            word = word.lower()
            if word in freq_dict:
                freq_dict[word] += 1
            else:
                freq_dict[word] = 1
            temp = {'doc_id' : i,'freq_dict' : freq_dict}
        freqDict_list.append(temp) 
    return freqDict_list   


def computeTF(doc_info,dreqDict_list):
    TF_scores = []
    for tempDict in freqDict_list:
        id = tempDict['doc_id']
        for k in tempDict['freq_dict']:
            temp = {'doc_id' : id,
                   'TF_score' : tempDict['freq_dict'][k]/doc_info[id-1]['doc_length'],'key' : k}
            TF_scores.append(temp)   
    return TF_scores       


def computeIDF(doc_info, freqDict_list):
    IDF_scores = []
    counter = 0
    for dict in freqDict_list:
        counter += 1
        for k in dict['freq_dict'].keys():
            count = sum([k in tempDict['freq_dict'] for tempDict in freqDict_list])
            temp = {'doc_id' : counter,'IDF_scores': math.log(len(doc_info)/count), 'key' : k}
            
            IDF_scores.append(temp)
            
    return IDF_scores   



def computeTFIDF(TF_scores,IDF_scores):
    TFIDF_scores = []
    for j in IDF_scores:
        for i in TF_scores:
            if j['key'] == i['key'] and j['doc_id'] == i['doc_id']:
                temp = {'doc_id' : j['doc_id'],
                       'TFIDF_score' : j['IDF_score']*i['TF_score'],
                       'key' : i['key']}
        TFIDF_scores.append(temp)
    return TFIDF_scores   

enc = 'utf-8'
file = open('filter.txt','r', encoding = enc)
text = file.read()

text_sents = sent_tokenize(text)

text_sents_clean = [remove_string_special_character(s) for s in text_sents]

doc_info = get_doc(text_sents_clean)

freqDict_list = create_freq_dict(text_sents_clean)
TF_scores = computeTF(doc_info,freqDict_list)

IDF_scores = computeIDF(doc_info,freqDict_list)
for sc in IDF_scores:
    print(sc)
# Out:
# {'doc_id': 1, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 2, 'IDF_scores': 6.75110146893676, 'key': 'theyincludedtheforumsfinancialservicesinnovationandtechnologycommunitiesprofessionalsfromacademiaandthepublicsector'}
# {'doc_id': 3, 'IDF_scores': 6.75110146893676, 'key': 'theoutreachinvolvedover150interviewsand10internationalworkshopsessionsencouragingcollaborativedialoguetodiscussinsightsandopportunitiesconcerningfintechdisruptionwithinthefinancialservicesindustry'}
# {'doc_id': 4, 'IDF_scores': 6.75110146893676, 'key': 'theholisticandglobalperspectiveofthisreportwouldnotbeasenrichedwithoutthesupportandcontributionsfromthesubjectmatterexpertswhoassistedindrivingourthoughtsforwardaboutthefutureofthefinancialservicesindustry'}
# {'doc_id': 5, 'IDF_scores': 6.75110146893676, 'key': 'inparticularwethankthisprojectssteeringcommitteeandworkinggroupintroducedintheacknowledgementssectionwhichplayedaninvaluablerolewiththeirexpertiseandpatientmentorship'}
# {'doc_id': 6, 'IDF_scores': 6.75110146893676, 'key': 'alsocriticalhasbeentheongoinginstitutionalsupportforthisinitiativefromtheforumandtheleadershipofourchairmanwhosevisionofthefourthindustrialrevolutionhasbeeninspirationaltothiswork'}
# {'doc_id': 7, 'IDF_scores': 6.75110146893676, 'key': 'finallywearegratefultodeloitteconsultingllpintheunitedstatesanentitywithinthedeloitte1networkforitsgenerouscommitmentandsupportinitscapacityastheofficialprofessionalservicesadvisertotheforumforthisproject'}
# {'doc_id': 8, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 9, 'IDF_scores': 6.75110146893676, 'key': 'dttlandeachofitsmemberfirmsarelegallyseparateandindependententities'}
# {'doc_id': 10, 'IDF_scores': 6.75110146893676, 'key': 'dttlalsoreferredtoasdeloitteglobaldoesnotprovideservicestoclients'}
# {'doc_id': 11, 'IDF_scores': 6.75110146893676, 'key': 'pleaseseewwwdeloittecomaboutforamoredetaileddescriptionofdttlanditsmemberfirms'}
# {'doc_id': 12, 'IDF_scores': 6.75110146893676, 'key': 'pleaseseewwwdeloittecomusaboutforadetaileddescriptionofthelegalstructureofdeloittellpanditssubsidiaries'}
# {'doc_id': 13, 'IDF_scores': 6.75110146893676, 'key': 'certainservicesmaynotbeavailabletoattestclientsundertherulesandregulationsofpublicaccounting'}
# {'doc_id': 14, 'IDF_scores': 6.75110146893676, 'key': 'thispublicationcontainsgeneralinformationonlyanddeloitteisnotbymeansofthispublicationrenderingaccountingbusinessfinancialinvestmentlegaltaxorotherprofessionaladviceorservices'}
# {'doc_id': 15, 'IDF_scores': 6.75110146893676, 'key': 'thispublicationisnotasubstituteforsuchprofessionaladviceorservicesnorshoulditbeusedasabasisforanydecisionoractionthatmayaffectyourbusiness'}
# {'doc_id': 16, 'IDF_scores': 6.75110146893676, 'key': 'beforemakinganydecisionortakinganyactionthatmayaffectyourbusinessyoushouldconsultaqualifiedprofessionaladviser'}
# {'doc_id': 17, 'IDF_scores': 6.75110146893676, 'key': 'deloitteshallnotberesponsibleforanylosssustainedbyanypersonwhoreliesonthispublication'}
# {'doc_id': 18, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 19, 'IDF_scores': 6.75110146893676, 'key': 'butinthewingsanewchallengeforthefinancialsystemwasgrowingintheformoffintechnewentrantsthatpromisedtorapidlyreshapehowfinancialproductswerestructuredprovisionedandconsumed'}
# {'doc_id': 20, 'IDF_scores': 6.75110146893676, 'key': 'nearlyfouryearslaterasthisinitiativedrawstoaclosewetaketheopportunitytoreflectonthechangestothefinancialsystemtakingstockoftheimpactsthatfintechshavehadandconsideringtheirevolvingrelationshipswithbothincumbentsandregulators'}
# {'doc_id': 21, 'IDF_scores': 6.75110146893676, 'key': 'moreimportantlyitpresentsanopportunitytoconsiderwhatliesbeyondthehorizonforfinancialservices'}
# {'doc_id': 22, 'IDF_scores': 6.75110146893676, 'key': 'thetechnologiesofthefourthindustrialrevolutionhavetriggeredaseismicshiftinthefinancialsystemtheimplicationsofwhichwillextendfarbeyondthefintechsthatpioneeredtheiruseinfinancialservices'}
# {'doc_id': 23, 'IDF_scores': 6.75110146893676, 'key': 'valuechainsthathavecharacterizedtheindustryfordecadesarebeingdisruptedandreshapedwithimplicationsforcustomersregulatorsincumbentsandeveryotherstakeholderinthefinancialsystem'}
# {'doc_id': 24, 'IDF_scores': 6.75110146893676, 'key': 'inthisfourthreportofthefutureoffinancialservicesserieswehopetobuilduponourpreviousworkandprovidethemanystakeholdersofthefinancialsystemwithabetterunderstandingoftheforcestransformingfinancialservicesaswellasanoutlookforitsfuture'}
# {'doc_id': 25, 'IDF_scores': 6.75110146893676, 'key': 'rjessemcwatersprojectleaddisruptiveinnovationinfinancialservicesworldeconomicforumrobgalaskiamericasfinancialservicesleaderdeloitte5contents1'}
# {'doc_id': 26, 'IDF_scores': 6.75110146893676, 'key': 'contextandapproach2'}
# {'doc_id': 27, 'IDF_scores': 6.75110146893676, 'key': 'keyfindingsanduncertainties'}
# {'doc_id': 28, 'IDF_scores': 4.553876891600541, 'key': '3'}
# {'doc_id': 29, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 30, 'IDF_scores': 6.75110146893676, 'key': 'itfocusedonestablishingacleartaxonomyforunderstandingwhichfintechinnovationsarethemostrelevantmappingpossiblefuturesfortheevolutionarypathsofemergingfintechinnovationsexploringtheimplicationsoffintechonkeystakeholdersconsumersincumbentsregulatorsetc'}
# {'doc_id': 31, 'IDF_scores': 6.75110146893676, 'key': 'phase1outcomesarecapturedinthereportthefutureoffinancialservicesphase2phase2aimedtoillustratetheroleoffinancialinfrastructureinenablingthefutureoffinancialservices'}
# {'doc_id': 32, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 33, 'IDF_scores': 6.75110146893676, 'key': 'inthisdocumentwedefineafintechtobeasmalltechnologyenablednewentranttofinancialservices'}
# {'doc_id': 34, 'IDF_scores': 6.75110146893676, 'key': 'thisdefinitiondoesnotincludelargetechnologyfirmsthatenterfinancialserviceseg'}
# {'doc_id': 35, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 36, 'IDF_scores': 6.75110146893676, 'key': 'italsoconsidersevolutionarypathsforthefutureofthesystemaswellastheirimplicationsforstakeholdersreportquestions123whataretheinnovationsthathavemadethemostimpactonthefinancialecosystemsincethe2015reportandwhataretheideasthathavefailedtoproduceimpact'}
# {'doc_id': 37, 'IDF_scores': 6.75110146893676, 'key': 'howwilltheseinnovationsimpactthewaysinwhichfinancialservicesarestructuredprovisionedandconsumedinthefuture'}
# {'doc_id': 38, 'IDF_scores': 6.75110146893676, 'key': 'whatwillbetheimplicationsoftheseinnovationsonthebroaderfinancialsystem'}
# {'doc_id': 39, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 40, 'IDF_scores': 6.75110146893676, 'key': 'throughinnovationslikerapidloanadjudicationfintechshaveshownthatthecustomerexperiencebarsetbylargetechnologyfirmssuchasappleandgooglecanbemetinfinancialservicesconclusioncustomerwillingnesstoswitchawayfromincumbentshasbeenoverestimated'}
# {'doc_id': 41, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 42, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 43, 'IDF_scores': 6.75110146893676, 'key': '...ō...'}
# {'doc_id': 44, 'IDF_scores': 6.75110146893676, 'key': 'hbr2'}
# {'doc_id': 45, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 46, 'IDF_scores': 6.75110146893676, 'key': 'ft4'}
# {'doc_id': 47, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 48, 'IDF_scores': 6.75110146893676, 'key': 'howcanfirmsextractthemostrevenuesfromthedataavailabletothem'}
# {'doc_id': 49, 'IDF_scores': 6.75110146893676, 'key': 'howmuchwillitcost'}
# {'doc_id': 50, 'IDF_scores': 6.75110146893676, 'key': 'howwillfinancialservicesfirmsmitigateriskwhentechnologyracesaheadofmanagementsabilitytounderstandtheconsequences'}
# {'doc_id': 51, 'IDF_scores': 6.75110146893676, 'key': 'systemictransparencycooperationproblemshowwillthetransparencybuiltintonewsystemsimpacttheirdesignparticipantsrolesortheirprofitmodels'}
# {'doc_id': 52, 'IDF_scores': 6.75110146893676, 'key': 'canfinancialservicesfirmsusetechnologytosolvelongrunningpartnershipandcollaborationissuesthatlieattheheartoftheindustry'}
# {'doc_id': 53, 'IDF_scores': 6.75110146893676, 'key': 'contextapproachkeyfindingskeyuncertainties31keyfindingsreferencesreferences1'}
# {'doc_id': 54, 'IDF_scores': 4.671659927256925, 'key': '2'}
# {'doc_id': 55, 'IDF_scores': 4.553876891600541, 'key': '3'}
# {'doc_id': 56, 'IDF_scores': 4.805191319881447, 'key': '4'}
# {'doc_id': 57, 'IDF_scores': 6.75110146893676, 'key': 'howartificialintelligencewillredefinemanagement'}
# {'doc_id': 58, 'IDF_scores': 6.75110146893676, 'key': 'harvardbusinessreviewhbr'}
# {'doc_id': 59, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpshbrorg201611howartificialintelligencewillredefinemanagementareyoureadyforrobotcolleagues'}
# {'doc_id': 60, 'IDF_scores': 6.75110146893676, 'key': 'mitsloanmanagementreview'}
# {'doc_id': 61, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpsloanreviewmiteduarticleareyoureadyforrobotcolleaguesjpmorganchaseinpushtominecustomerdata'}
# {'doc_id': 62, 'IDF_scores': 6.75110146893676, 'key': 'financialtimesft'}
# {'doc_id': 63, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwftcomcontent1eaf6436e4a211e69645c9357a75844acdointerviewmacquariebankinggroupsdigitalleaderondeliveringcustomertrust'}
# {'doc_id': 64, 'IDF_scores': 6.75110146893676, 'key': 'cmofromidg'}
# {'doc_id': 65, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 66, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 67, 'IDF_scores': 6.75110146893676, 'key': 'willincumbentpaymentnetworksbeabletorespondtonewentrantspaymentsinfrastructure'}
# {'doc_id': 68, 'IDF_scores': 6.75110146893676, 'key': 'whatrolewillpaymentsplayinthebroadersuiteofofferingsfromfinancialinstitutions'}
# {'doc_id': 69, 'IDF_scores': 6.75110146893676, 'key': 'willtheriseofmultinationalseg'}
# {'doc_id': 70, 'IDF_scores': 6.75110146893676, 'key': 'applepayleadtoglobalpaymentconvergence'}
# {'doc_id': 71, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 72, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 73, 'IDF_scores': 6.75110146893676, 'key': 'demobilepaymentsolutionshavenotsufficientlyexceededthefunctionalityofpreexistingsolutionsincardbasedmarketsthuslimitingtheiradoptioncustomeracceptanceofnontraditionalpaymentschemeseg'}
# {'doc_id': 74, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 75, 'IDF_scores': 6.75110146893676, 'key': 'amazonisalsocreatinganecosystemarounditsoneclickpaymentservicebyrollingitouttoothermerchantsindirectcompetitionwithpaypalforexample'}
# {'doc_id': 76, 'IDF_scores': 6.75110146893676, 'key': 'thegrowthofchinasinpersonretailshoppingmarketslowedto10innovember20162itslowestlevelofgrowthinoveradecadeascustomersshiftedtheirshoppingfromretailtoonlinechannels'}
# {'doc_id': 77, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 78, 'IDF_scores': 6.75110146893676, 'key': 'amazonstripeexpandintoinpersonretailandifsocantheyachievescale'}
# {'doc_id': 79, 'IDF_scores': 4.805191319881447, 'key': 'sources1'}
# {'doc_id': 80, 'IDF_scores': 6.75110146893676, 'key': 'sliceintelligence2'}
# {'doc_id': 81, 'IDF_scores': 6.75110146893676, 'key': 'ft3'}
# {'doc_id': 82, 'IDF_scores': 6.75110146893676, 'key': 'cnbc4'}
# {'doc_id': 83, 'IDF_scores': 6.75110146893676, 'key': 'fortunecom2howwillcardnetworksreacttotherisingimportanceoflargetechsinonlinepayments'}
# {'doc_id': 84, 'IDF_scores': 6.75110146893676, 'key': '3inemergingmarketscanincumbentsenterandovercomelocallybuiltsolutions'}
# {'doc_id': 85, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 86, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 87, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 88, 'IDF_scores': 6.75110146893676, 'key': 'ascustomersmovetonewplatforms'}
# {'doc_id': 89, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 90, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 91, 'IDF_scores': 6.75110146893676, 'key': 'ithasannouncedpartnershipswithn26ingermanystarlingintheunitedkingdomandlhvinestoniathecountryslargestlocalbank'}
# {'doc_id': 92, 'IDF_scores': 6.75110146893676, 'key': 'lendingclubaswellasmanyofitscompetitorsinthealternativelendingsectorhaslongadvertisedtotherevolvingcreditmarkethighlightinglowerinterestratestheabsenceofadditionalfeesandtheabilitytoraisecreditscores'}
# {'doc_id': 93, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 94, 'IDF_scores': 6.75110146893676, 'key': '2canbankspaymentprovidersgeneratealternativeformsofrevenuefromfasterpaymentschemes'}
# {'doc_id': 95, 'IDF_scores': 6.75110146893676, 'key': '3willtraditionalfxsolutionscompeteorpartnerwithnewfintechenabledsolutions'}
# {'doc_id': 96, 'IDF_scores': 6.0579542883768145, 'key': 'sources5'}
# {'doc_id': 97, 'IDF_scores': 6.75110146893676, 'key': 'lendingclubcom6'}
# {'doc_id': 98, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 99, 'IDF_scores': 6.75110146893676, 'key': 'asaresultadoptionhasdifferedconsiderablybyregiondependingonthedegreeofunmetneedsubiquityoftechnologywhethernewpaymenttechnologyisubiquitousalsogreatlyaffectstheadoptionofpaymentsolutions'}
# {'doc_id': 100, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 101, 'IDF_scores': 6.75110146893676, 'key': 'incanadaregulationdrovemuchearlieradoptionofemvsmartorchipcardscomparedtointheunitedsateswhereretailerpressureslowedrollout'}
# {'doc_id': 102, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 103, 'IDF_scores': 6.75110146893676, 'key': '2willdemonetizationschemescatchoninotherpartsoftheworld'}
# {'doc_id': 104, 'IDF_scores': 6.75110146893676, 'key': '3howwillthedivergingpaymentsecosystemaffectonlinetransactionsifatall'}
# {'doc_id': 105, 'IDF_scores': 5.36480710781687, 'key': 'sources7'}
# {'doc_id': 106, 'IDF_scores': 6.75110146893676, 'key': 'technavio8'}
# {'doc_id': 107, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 108, 'IDF_scores': 6.75110146893676, 'key': 'howwilleuregulatorsmonitorandenforcethedegreeofinstitutionalcompliancewithpsd2andwillthisdifferbycountry'}
# {'doc_id': 109, 'IDF_scores': 6.75110146893676, 'key': 'willthisdriveinnovationatthemerchantintermediarylevelandwillcustomersadapt'}
# {'doc_id': 110, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 111, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 112, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 113, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 114, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 115, 'IDF_scores': 6.75110146893676, 'key': '2doesusingamobilepaymentsolutionhaveadditionaladvantagesyettobeunlocked'}
# {'doc_id': 116, 'IDF_scores': 6.75110146893676, 'key': '3willsuccessfulincumbentsfromemergingmarketsbeabletoentercardbasedmarkets'}
# {'doc_id': 117, 'IDF_scores': 5.14166355650266, 'key': 'sources10'}
# {'doc_id': 118, 'IDF_scores': 6.75110146893676, 'key': 'pymntscom11'}
# {'doc_id': 119, 'IDF_scores': 6.75110146893676, 'key': 'arstechnica12'}
# {'doc_id': 120, 'IDF_scores': 6.75110146893676, 'key': 'forbesintroductionfindingsabcdeuncertaintiesendstatesconclusion46paymentsfindingecustomeracceptanceofnontraditionalpaymentschemeseg'}
# {'doc_id': 121, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 122, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 123, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 124, 'IDF_scores': 6.75110146893676, 'key': 'recentlythelimitforprocessinghasbeenraisedto250000forbusinesspaymentsallowingthesystemtohandlethevastmajorityofbusinesstransactions'}
# {'doc_id': 125, 'IDF_scores': 6.75110146893676, 'key': 'bitcoinexchangehacks42transactionsperdayapril2017million1415concernsregardingthesecurityofexchangesandwalletsarepervasiveamongusersofbitcoinandotherdigitalcurrencies'}
# {'doc_id': 126, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 127, 'IDF_scores': 6.75110146893676, 'key': '2willdifferentpaymentmodernizationstandardsaffectthedevelopmentofcrossbordersolutions'}
# {'doc_id': 128, 'IDF_scores': 6.75110146893676, 'key': '3howwillbankscontinuetojustifyhighpaymentfeesoncemodernsystemsareimplemented'}
# {'doc_id': 129, 'IDF_scores': 6.0579542883768145, 'key': 'sources13'}
# {'doc_id': 130, 'IDF_scores': 6.75110146893676, 'key': 'thewallstreetjournal14'}
# {'doc_id': 131, 'IDF_scores': 6.75110146893676, 'key': 'fasterpayments15'}
# {'doc_id': 132, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 133, 'IDF_scores': 6.75110146893676, 'key': 'ontheonehandheightenedcompetitionandachallengingregulatoryenvironmentareleadingtosteadilydecliningprofits'}
# {'doc_id': 134, 'IDF_scores': 6.75110146893676, 'key': 'ontheothercustomersarereluctanttoswitchtonontraditionalpaymentschemeswithoutseeingsignificantbenefitstherebylimitingadoptionofnewtechnologies'}
# {'doc_id': 135, 'IDF_scores': 6.75110146893676, 'key': 'throughthesefindingsthefollowingkeyuncertaintiesaboutthefutureofpaymentsemerged2uncertaintieswillthefutureofpaymentsdivergeintotwoworldsretailandonlineorcantheybebridged'}
# {'doc_id': 136, 'IDF_scores': 6.75110146893676, 'key': 'whoisbestpositionedtobenefitfromthemonetizationofpaymentsdata'}
# {'doc_id': 137, 'IDF_scores': 6.75110146893676, 'key': 'willpsd2successfullycreatenewpaymentsvaluechainsineurope'}
# {'doc_id': 138, 'IDF_scores': 6.75110146893676, 'key': 'willmobilepaymentsevercaptureamajordoubledigitshareofretailpaymentsincardbasedcountries'}
# {'doc_id': 139, 'IDF_scores': 6.75110146893676, 'key': 'whatwillthefirstnationaldigitalcurrencylooklikeandhowfarawayisit'}
# {'doc_id': 140, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 141, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 142, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 143, 'IDF_scores': 6.75110146893676, 'key': 'datastreamswillbesignificantlymorevaluablewheretheyaregranulareg'}
# {'doc_id': 144, 'IDF_scores': 6.75110146893676, 'key': 'productleveldataandmultidimensionaleg'}
# {'doc_id': 145, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 146, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 147, 'IDF_scores': 6.75110146893676, 'key': 'combinedwiththeincreasedimportanceofproductlevelpaymentsdatamerchantswillbeabletowieldthispowertolowerfeesandinfluencethebroaderevolutionofpaymentsecosystemsintroductionfindingsuncertaintiesendstatesconclusion57paymentsreferencesreferences1'}
# {'doc_id': 148, 'IDF_scores': 4.671659927256925, 'key': '2'}
# {'doc_id': 149, 'IDF_scores': 4.553876891600541, 'key': '3'}
# {'doc_id': 150, 'IDF_scores': 4.805191319881447, 'key': '4'}
# {'doc_id': 151, 'IDF_scores': 4.959341999708705, 'key': '5'}
# {'doc_id': 152, 'IDF_scores': 4.805191319881447, 'key': '6'}
# {'doc_id': 153, 'IDF_scores': 4.805191319881447, 'key': '7'}
# {'doc_id': 154, 'IDF_scores': 4.959341999708705, 'key': '8'}
# {'doc_id': 155, 'IDF_scores': 5.14166355650266, 'key': '9'}
# {'doc_id': 156, 'IDF_scores': 6.75110146893676, 'key': 'echoturnsupthevolumeonamazonsambitionsasaudaciousbetspayoff'}
# {'doc_id': 157, 'IDF_scores': 6.75110146893676, 'key': 'sliceintelligence'}
# {'doc_id': 158, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpsintelligenceslicecomechoturnsvolumeamazonsambitionsaudaciousbetspayoffchinaretailinvestmentandindustrialproductiongrowthsofteninapril'}
# {'doc_id': 159, 'IDF_scores': 6.0579542883768145, 'key': 'financialtimes'}
# {'doc_id': 160, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwftcomcontentd9f71364e2bf345da4e9a61c9a9058a7mhq5je3singlesdayalibabasmashesrecordsatworldslargestonlineshoppingevent'}
# {'doc_id': 161, 'IDF_scores': 5.652489180268651, 'key': 'cnbc'}
# {'doc_id': 162, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwcnbccom20161111singlesdaynewsalibabapoisedtosmashrecordsatworldslargestonlineshoppingeventhtmlabout10millionmoreamericansshoppedonlinethaninstoresoverblackfridayweekend'}
# {'doc_id': 163, 'IDF_scores': 6.75110146893676, 'key': 'fortunecom'}
# {'doc_id': 164, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpfortunecom20161127blackfridaynrfshoppingstatisticaccordingtolendingclubcomwheredoesmymoneygo'}
# {'doc_id': 165, 'IDF_scores': 6.75110146893676, 'key': 'interchangefeesexplained'}
# {'doc_id': 166, 'IDF_scores': 6.75110146893676, 'key': 'findercomau'}
# {'doc_id': 167, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwfindercomauwheredoesmymoneygointerchangefeesexplainedhowthedemonetizationofindiancurrencyhasledtoincreaseduseofmobilewallets'}
# {'doc_id': 168, 'IDF_scores': 6.75110146893676, 'key': 'technavio'}
# {'doc_id': 169, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwtechnaviocombloghowdemonetizationindiancurrencyhasledincreasedusemobilewalletsworldwideemvdeploymentstatistics'}
# {'doc_id': 170, 'IDF_scores': 6.75110146893676, 'key': 'emvco'}
# {'doc_id': 171, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwemvcocomabout_emvcoaspxid202consumercashusageacrosscountrycomparisonwithpaymentdiarysurveydata'}
# {'doc_id': 172, 'IDF_scores': 6.75110146893676, 'key': 'johnbagnalletalpublishedininternationaljournalofcentralbanking'}
# {'doc_id': 173, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwijcborgjournalijcb16q4a1pdf10'}
# {'doc_id': 174, 'IDF_scores': 6.75110146893676, 'key': 'applepaystats'}
# {'doc_id': 175, 'IDF_scores': 6.75110146893676, 'key': 'pymntscom'}
# {'doc_id': 176, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwpymntscomapplepayadoption11'}
# {'doc_id': 177, 'IDF_scores': 6.75110146893676, 'key': 'currentcretailersdefiantanswertoapplepaywilldeactivateitsuseraccounts'}
# {'doc_id': 178, 'IDF_scores': 6.75110146893676, 'key': 'arstechnica'}
# {'doc_id': 179, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpsarstechnicacombusiness201606currentcretailersdefiantanswertoapplepaywilldeactivateitsuseraccounts12'}
# {'doc_id': 180, 'IDF_scores': 6.75110146893676, 'key': 'alipaytakesonapplepayandpaypalontheirhometurf'}
# {'doc_id': 181, 'IDF_scores': 4.805191319881447, 'key': 'forbes'}
# {'doc_id': 182, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwforbescomsiteshelenwang20161030willalipaydominateglobalmobilepayments13'}
# {'doc_id': 183, 'IDF_scores': 6.75110146893676, 'key': 'bitcoinexchangetospreadlossesofhack'}
# {'doc_id': 184, 'IDF_scores': 5.652489180268651, 'key': 'thewallstreetjournal'}
# {'doc_id': 185, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwwsjcomarticlesbitfinextospreadlossesfromcybertheftamongallusers147055986514'}
# {'doc_id': 186, 'IDF_scores': 6.75110146893676, 'key': 'statistics'}
# {'doc_id': 187, 'IDF_scores': 6.75110146893676, 'key': 'fasterpayments'}
# {'doc_id': 188, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwfasterpaymentsorgukaboutusstatistics15'}
# {'doc_id': 189, 'IDF_scores': 6.75110146893676, 'key': 'confirmedtransactionsperday'}
# {'doc_id': 190, 'IDF_scores': 6.75110146893676, 'key': 'blockchaininfo'}
# {'doc_id': 191, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpsblockchaininfochartsntransactionsintroductionfindingsuncertaintiesendstatesconclusion58section32insuranceworldeconomicforum201759insuranceintroductioninsurancehasgreatlyevolvedinthelastseveralyears'}
# {'doc_id': 192, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 193, 'IDF_scores': 6.75110146893676, 'key': 'wouldinsuranceproductschangeduetochangingcustomerlifestyles'}
# {'doc_id': 194, 'IDF_scores': 6.75110146893676, 'key': 'wouldconnectedproductsreachmassadoptionacrossalltypesofinsurance'}
# {'doc_id': 195, 'IDF_scores': 6.75110146893676, 'key': 'howwouldthedevelopmentoflifeinsuranceevolveasgrowthmarketsshift'}
# {'doc_id': 196, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 197, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 198, 'IDF_scores': 6.75110146893676, 'key': 'uberairbnborteslacreatingnewengagementmodelsforinsurersandnecessitatingashiftininsuranceproductdesignovercapitalizationtheinsuranceindustryisovercapitalizedasawholeleadingtolowerreturns'}
# {'doc_id': 199, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 200, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 201, 'IDF_scores': 6.75110146893676, 'key': 'teslabelievesthatwithitsimprovingautopilotandsafetyfeaturestheriskprofileofitscarswillonlyimproveovertime'}
# {'doc_id': 202, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 203, 'IDF_scores': 4.805191319881447, 'key': 'sources1'}
# {'doc_id': 204, 'IDF_scores': 6.75110146893676, 'key': 'ft2'}
# {'doc_id': 205, 'IDF_scores': 6.75110146893676, 'key': 'mashable3'}
# {'doc_id': 206, 'IDF_scores': 6.75110146893676, 'key': 'swissre2howwillinsurersguardagainsttheerosionoftheirprofitabilityfrominstitutionalmoney'}
# {'doc_id': 207, 'IDF_scores': 6.75110146893676, 'key': '3towhatextentwillinsurancegetsubsumedwithintheactualproductorservicebeingpurchased'}
# {'doc_id': 208, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 209, 'IDF_scores': 6.75110146893676, 'key': 'howeverquestionsremainabouthowneedswillbemeasuredandrisksassessedsupportingevidenceriseoftheprosumerthelinebetweentheconsumerandabusinessisblurringwiththeriseoftheprosumermeaningthatconsumersneeddifferentcoveragesdependingonwhattheyredoing'}
# {'doc_id': 210, 'IDF_scores': 6.75110146893676, 'key': 'asaresultinsurersmustshifttheirdelineationbetweenpersonalandcommercialinsuranceinordertomeetcustomerneedsmicroinsuranceinsurtechstartupsareofferingeversmallerslicesofinsuranceforindividualproductseg'}
# {'doc_id': 211, 'IDF_scores': 6.75110146893676, 'key': 'customersmobilephonesorforsmalleramountsoftimethatcustomerscanchooseeg'}
# {'doc_id': 212, 'IDF_scores': 6.75110146893676, 'key': 'forapotentiallydelayedflight'}
# {'doc_id': 213, 'IDF_scores': 6.75110146893676, 'key': 'thiswilltestthelimitsofinsuranceproductdesignandnecessitateondemandsalesadaptableinsuranceconsumersaredemandingmodularityfortheirinsuranceindifferentlocationsfordifferentusecaseseg'}
# {'doc_id': 214, 'IDF_scores': 6.75110146893676, 'key': 'coverageforhighvalueitemsandfordifferentusagepatternseg'}
# {'doc_id': 215, 'IDF_scores': 6.75110146893676, 'key': 'coveragesthatcaneasilybeturnedonandoff'}
# {'doc_id': 216, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 217, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 218, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 219, 'IDF_scores': 6.75110146893676, 'key': '2microinsurancepresumesanincreasedlevelofengagementbetweencustomersandtheinsurerdocustomerswantthis'}
# {'doc_id': 220, 'IDF_scores': 6.75110146893676, 'key': '3howwilltherolloutofadaptableinsuranceimpactcustomerswhopreviouslybenefittedfromnonmodularproducts'}
# {'doc_id': 221, 'IDF_scores': 5.36480710781687, 'key': 'sources4'}
# {'doc_id': 222, 'IDF_scores': 6.75110146893676, 'key': 'airbnb5'}
# {'doc_id': 223, 'IDF_scores': 6.75110146893676, 'key': 'insurancejournal6'}
# {'doc_id': 224, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 225, 'IDF_scores': 6.75110146893676, 'key': 'keyuncertaintiesladderandhavenlifeareusinsurersthathaverecentlystartedtooffertermlifeproductswithoutamedicalcheckforthemajorityofapplicants8ladderisaninsurtechstartupwhereashavenlifeisawhollyownedsubsidiaryofmassmutual'}
# {'doc_id': 226, 'IDF_scores': 6.75110146893676, 'key': 'asaresulttheyrepresenttwopathsforthelifeinsuranceindustrytoofferdigitalproducts'}
# {'doc_id': 227, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 228, 'IDF_scores': 6.75110146893676, 'key': '2howwillinsurersacquiretheinformationtheyneedtobypassthemedicalcheckandhowwillthisdifferbyregion'}
# {'doc_id': 229, 'IDF_scores': 6.75110146893676, 'key': '3howwilltraditionalinsurersmanagetheshifttosimplertermproductsintheircorebusinesseswithoutcannibalization'}
# {'doc_id': 230, 'IDF_scores': 6.75110146893676, 'key': 'sources7businessinsider8'}
# {'doc_id': 231, 'IDF_scores': 6.75110146893676, 'key': 'nerdwallet9'}
# {'doc_id': 232, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 233, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 234, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 235, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 236, 'IDF_scores': 6.75110146893676, 'key': 'keyuncertaintiesconnectedmonitoringforchurchesacommercialinsurancecompanyrecentlylaunchedaproductwithchurchmutualtoprotectchurchesagainstfrozenpipeleakschurchesareespeciallyvulnerableduetolowoccupancy'}
# {'doc_id': 237, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 238, 'IDF_scores': 6.75110146893676, 'key': '2willtheriseofinsurancepremiumsonnewrisksandinnewmarketsbalanceoutthelossoftraditionalrisksandmarkets'}
# {'doc_id': 239, 'IDF_scores': 6.75110146893676, 'key': '3withtheshifttopreventioninsurerswillmoveintoareascurrentlyoccupiedbylargetechshowwillthisaffectpartnerships'}
# {'doc_id': 240, 'IDF_scores': 5.14166355650266, 'key': 'sources10'}
# {'doc_id': 241, 'IDF_scores': 6.75110146893676, 'key': 'insurancejournal11'}
# {'doc_id': 242, 'IDF_scores': 6.75110146893676, 'key': 'yahoofinance12'}
# {'doc_id': 243, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 244, 'IDF_scores': 6.75110146893676, 'key': 'moreoverregulatorsinsomelocalesareworkingdirectlywithcompaniesinordertoensuredatasecuritytheriseoftimemeasuredinsurancetraditionallyinsuranceproductshaveworkedonafixedtimebasiswherethepricewouldbedirectlylinkedtothecustomersriskprofile'}
# {'doc_id': 245, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 246, 'IDF_scores': 6.75110146893676, 'key': 'inmostinstanceshoweverthatconnectionrequirescustomeragreementroleofassistantswithincreasinguseofvirtualassistantsbyamazongoogleandmicrosoftandassuchassistantscollectmoreinformationabouttheirownerstheymaybecomeavirtualinsuranceagentforhouseholds'}
# {'doc_id': 247, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 248, 'IDF_scores': 6.75110146893676, 'key': 'customershavethechoicetooptintotheprogrammeearningvitalitypointsbytrackingdailyhealthrelatedactivities'}
# {'doc_id': 249, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 250, 'IDF_scores': 6.75110146893676, 'key': 'customerssavejustbyhavingarequiredhomesafetydevicemakingadoptionpainfree'}
# {'doc_id': 251, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 252, 'IDF_scores': 6.0579542883768145, 'key': 'sources13'}
# {'doc_id': 253, 'IDF_scores': 6.75110146893676, 'key': 'johnhancock14'}
# {'doc_id': 254, 'IDF_scores': 6.75110146893676, 'key': 'nest15'}
# {'doc_id': 255, 'IDF_scores': 6.75110146893676, 'key': 'ey2whatwillbetheimpactoftimebasedinsuranceontheperunitpriceofinsurance'}
# {'doc_id': 256, 'IDF_scores': 6.75110146893676, 'key': '3howwillthedevelopmentofassistantsaroundclosedecosystemssirialexaimpactthepurchaseofinsurance'}
# {'doc_id': 257, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 258, 'IDF_scores': 6.75110146893676, 'key': 'thevaluechainisunderenormouspressureandchangesinpurchasingpatternsareforcinginsurerstomoveawayfromthetraditionalonesizefitsallmodeltowardsaflexiblecustomizablerangeofproducts'}
# {'doc_id': 259, 'IDF_scores': 6.75110146893676, 'key': 'atthesametimeinsurersmustchangefrombeingreactivetobeingproactivewiththeriseofconnectedinsuranceandtheneedtomonitorcustomerriskonanongoingbasis'}
# {'doc_id': 260, 'IDF_scores': 6.75110146893676, 'key': 'throughthesefindingsthefollowingkeyuncertaintiesaroundthefutureofinsuranceemerged2uncertaintieshowwilltheinsuranceconsumptionmodelchangeasthesourcesandnatureofliabilitychangesinthefuture'}
# {'doc_id': 261, 'IDF_scores': 6.75110146893676, 'key': 'willtheindustrybeabletodevelopguidelinesfortheuseofdataandhowwillthoseguidelinesdifferaroundtheworld'}
# {'doc_id': 262, 'IDF_scores': 6.75110146893676, 'key': 'docustomerswanttoengagewiththeirinsurermoreoftenaswouldbeneededformicroinsurance'}
# {'doc_id': 263, 'IDF_scores': 6.75110146893676, 'key': 'howwillinsurersmatchtheirlifeproductstofitthedifferentconditionsinemergingmarkets'}
# {'doc_id': 264, 'IDF_scores': 6.75110146893676, 'key': 'willincreasingintegrationandafocusonpreventionleadtosuccessforconnectedproducts'}
# {'doc_id': 265, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 266, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 267, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 268, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 269, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 270, 'IDF_scores': 6.75110146893676, 'key': 'toachievethishoweverinsurersmustovercomeexistingperceptionsofconnectedinsuranceproductsconvincingcustomersthattheyrepresentanimprovementovercurrentproductsintroductionfindingsuncertaintiesendstatesconclusion82insurancereferencesreferences1'}
# {'doc_id': 271, 'IDF_scores': 4.671659927256925, 'key': '2'}
# {'doc_id': 272, 'IDF_scores': 4.553876891600541, 'key': '3'}
# {'doc_id': 273, 'IDF_scores': 4.805191319881447, 'key': '4'}
# {'doc_id': 274, 'IDF_scores': 4.959341999708705, 'key': '5'}
# {'doc_id': 275, 'IDF_scores': 4.805191319881447, 'key': '6'}
# {'doc_id': 276, 'IDF_scores': 4.805191319881447, 'key': '7'}
# {'doc_id': 277, 'IDF_scores': 6.75110146893676, 'key': 'boughtbymanyexpandsnicheinsurancerole'}
# {'doc_id': 278, 'IDF_scores': 6.75110146893676, 'key': 'ftretrievedfromhttpswwwftcomcontenta0d04746d9bc11e6944be7eb37a6aa8emhq5je3teslaissosureitscarsaresafethatitnowoffersinsuranceforlife'}
# {'doc_id': 279, 'IDF_scores': 6.75110146893676, 'key': 'mashable'}
# {'doc_id': 280, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpmashablecom20170223elonmuskteslalifetimeinsuranceuyplmbietkq3insurancelinkedsecuritiesmarketupdatevolumexxvifebruary2017'}
# {'doc_id': 281, 'IDF_scores': 6.75110146893676, 'key': 'swissre'}
# {'doc_id': 282, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwswissrecomlibraryils_market_update_february_2017htmlairbnbsgrowingcommunityof60womenhosts'}
# {'doc_id': 283, 'IDF_scores': 6.75110146893676, 'key': 'airbnb'}
# {'doc_id': 284, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwairbnbactioncomwpcontentuploads201603airbnb_60_plus_women_reportpdfslicelabstestingpayperuseinsuranceappwithridesharedrivers'}
# {'doc_id': 285, 'IDF_scores': 6.0579542883768145, 'key': 'insurancejournal'}
# {'doc_id': 286, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwinsurancejournalcomnewsnational20170403446575htmthesharingeconomygrowsuphowtheukhasembracedthesharingeconomy'}
# {'doc_id': 287, 'IDF_scores': 6.75110146893676, 'key': 'pwc'}
# {'doc_id': 288, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwpwccoukissuesmegatrendscollisionssharingeconomyoutlookforthesharingeconomyintheuk2016htmlthisswedishstartupbringsinsuranceto24millionpeopleinthedevelopingworldthroughtheirmobiles'}
# {'doc_id': 289, 'IDF_scores': 5.36480710781687, 'key': 'businessinsider'}
# {'doc_id': 290, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwbusinessinsidercombimabringsmicroinsurancetoafricaasiaandlatinamericaviaphones201610wheretofindonlineinstantapprovaltermlifeinsurance'}
# {'doc_id': 291, 'IDF_scores': 6.75110146893676, 'key': 'nerdwallet'}
# {'doc_id': 292, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwnerdwalletcombloginsuranceinstantlifeinsurance8'}
# {'doc_id': 293, 'IDF_scores': 5.14166355650266, 'key': '9'}
# {'doc_id': 294, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfrompopulationpyramidnet'}
# {'doc_id': 295, 'IDF_scores': 5.652489180268651, 'key': '10'}
# {'doc_id': 296, 'IDF_scores': 6.75110146893676, 'key': 'carpenterformspartnershipwithsymantectocreatecyberaggregationmodel'}
# {'doc_id': 297, 'IDF_scores': 6.0579542883768145, 'key': 'insurancejournal'}
# {'doc_id': 298, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwinsurancejournalcomnewsinternational20160518409001htm11'}
# {'doc_id': 299, 'IDF_scores': 6.75110146893676, 'key': 'churchmutualrecognizedasacelentmodelinsurerininnovationandemergingtechnologies'}
# {'doc_id': 300, 'IDF_scores': 6.0579542883768145, 'key': 'yahoofinance'}
# {'doc_id': 301, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpsfinanceyahoocomnewschurchmutualrecognizedcelentmodel190000478html12'}
# {'doc_id': 302, 'IDF_scores': 6.75110146893676, 'key': 'cyberinsurancepurchasingupbutbreachesfeltinpricesandlimits'}
# {'doc_id': 303, 'IDF_scores': 6.75110146893676, 'key': 'riskmanagementmonitorfrommarshanalysis'}
# {'doc_id': 304, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwriskmanagementmonitorcomcyberinsurancepurchasingupbutbreachesfeltinpricesandlimits13'}
# {'doc_id': 305, 'IDF_scores': 6.75110146893676, 'key': 'thejohnhancockvitalityprogram'}
# {'doc_id': 306, 'IDF_scores': 6.75110146893676, 'key': 'johnhancock'}
# {'doc_id': 307, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwjhrewardslifecomhowitworkshtml14'}
# {'doc_id': 308, 'IDF_scores': 6.75110146893676, 'key': 'staysafeandsavemoneywithnestandlibertymutual'}
# {'doc_id': 309, 'IDF_scores': 6.75110146893676, 'key': 'nest'}
# {'doc_id': 310, 'IDF_scores': 6.75110146893676, 'key': 'retrievedhttpsnestcominsurancepartnerslibertymutual15'}
# {'doc_id': 311, 'IDF_scores': 6.75110146893676, 'key': 'thequestfortelematics40creatingsustainablevaluepropositionsforconnectedcar'}
# {'doc_id': 312, 'IDF_scores': 6.0579542883768145, 'key': 'ey'}
# {'doc_id': 313, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwweycompublicationvwluassetskey_telematics_considerations_for_the_telecoms_sectorfilethe_quest_for_telematics_ef0120pdfintroductionfindingsuncertaintiesendstatesconclusion83section33digitalbankingworldeconomicforum201784digitalbankingintroductiondigitalbankinghasgreatlyevolvedinthelastseveralyears'}
# {'doc_id': 314, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 315, 'IDF_scores': 6.75110146893676, 'key': 'howwouldtheemergenceofbankingplatformsaffectdevelopmentsindigitalbanking'}
# {'doc_id': 316, 'IDF_scores': 6.75110146893676, 'key': 'howwouldbanksbeabletodeploydigitalsolutionswithlegacyarchitecture'}
# {'doc_id': 317, 'IDF_scores': 6.75110146893676, 'key': 'introductionfindingsuncertaintiesendstatesconclusion85digitalbankingoverviewoffindingsbankingisonthecuspofsignificantdisruptionasregulationsandtechnologybegintolaythefoundationsofafundamentalshiftinthebusinessmodelwherediddisruptionoccur'}
# {'doc_id': 318, 'IDF_scores': 6.75110146893676, 'key': ''}
# ...
# {'doc_id': 747, 'IDF_scores': 6.75110146893676, 'key': 'blackrocktoinvestinicapitalnetwork'}
# {'doc_id': 748, 'IDF_scores': 6.75110146893676, 'key': 'businesswire'}
# {'doc_id': 749, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwbusinesswirecomnewshome20161215006121enblackrockinvesticapitalc2aenetwork12'}
# {'doc_id': 750, 'IDF_scores': 6.75110146893676, 'key': 'wherearetheynow2016'}
# {'doc_id': 751, 'IDF_scores': 6.75110146893676, 'key': 'altfidata'}
# {'doc_id': 752, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwaltficomdownloadwhere_are_they_now_2016introductionfindingsuncertaintiesendstatesconclusion167section37marketinfrastructureworldeconomicforum2017168marketinfrastructureintroductionmarketinfrastructurehasgreatlyevolvedinthelastseveralyears'}
# {'doc_id': 753, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 754, 'IDF_scores': 6.75110146893676, 'key': 'whateffectwouldcontinuedregulationhaveonthedevelopmentofnewtradingtools'}
# {'doc_id': 755, 'IDF_scores': 6.75110146893676, 'key': 'howwouldincumbentsseektorespondtonewtechnologiesusedbystartups'}
# {'doc_id': 756, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 757, 'IDF_scores': 6.75110146893676, 'key': 'fixedincomehascontinuedinrecentyearsfollowingthepathofequitymarkets'}
# {'doc_id': 758, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 759, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 760, 'IDF_scores': 6.75110146893676, 'key': 'interestrateswaps'}
# {'doc_id': 761, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 762, 'IDF_scores': 6.75110146893676, 'key': 'productsthatarerelativelyhomogenousandhavelowtradesizesareparticularlygoodfitsfortradingplatformsandhavemigratedquickly'}
# {'doc_id': 763, 'IDF_scores': 6.75110146893676, 'key': '...örsegrouphasboughta10mstakeintrumidayoungbondtradingplatform'}
# {'doc_id': 764, 'IDF_scores': 6.75110146893676, 'key': 'trumidsplatformfocusesonbringingelectronictradingtocorporatedebtanassetclasswheremosttradingtodayisstillconductedoverthephone1'}
# {'doc_id': 765, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 766, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 767, 'IDF_scores': 6.75110146893676, 'key': '2willregulatorsfurtherexpandthescopeofassetclasseswhichneedtobetradedviaelectronictradingplatforms'}
# {'doc_id': 768, 'IDF_scores': 6.75110146893676, 'key': '3canbuysidefirmsadjusttotherequirementsofdirectplatformaccessdisintermediatingthesellside'}
# {'doc_id': 769, 'IDF_scores': 4.805191319881447, 'key': 'sources1'}
# {'doc_id': 770, 'IDF_scores': 6.75110146893676, 'key': 'financialtimes2'}
# {'doc_id': 771, 'IDF_scores': 6.75110146893676, 'key': 'financialnews3'}
# {'doc_id': 772, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 773, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 774, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 775, 'IDF_scores': 6.75110146893676, 'key': 'theimpactofbrexitoncapitalmarketsisstillunclear'}
# {'doc_id': 776, 'IDF_scores': 6.75110146893676, 'key': 'severaleuregulatorshaveindicated5theywillnotallowbrokersbasedoutsidetheeuropeaneconomicareaincludingapostbrexitunitedkingdomtoofferthirdcountryenduserselectronicaccesstoexchangesresidingundertheeuropeanunionsjurisdiction'}
# {'doc_id': 777, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 778, 'IDF_scores': 6.75110146893676, 'key': '2willfreedupcapitalflowbackintooldbusinessmodelsorwillitcontributetofurtherplatforminnovation'}
# {'doc_id': 779, 'IDF_scores': 6.75110146893676, 'key': '3howdoesregionalfragmentationreshapethebusinessmodelsofplatformproviders'}
# {'doc_id': 780, 'IDF_scores': 5.36480710781687, 'key': 'sources4'}
# {'doc_id': 781, 'IDF_scores': 6.75110146893676, 'key': 'cftc5'}
# {'doc_id': 782, 'IDF_scores': 6.75110146893676, 'key': 'risknet6'}
# {'doc_id': 783, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 784, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 785, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 786, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 787, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 788, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 789, 'IDF_scores': 6.75110146893676, 'key': '2willdisruptionattractcapitalheavytechnologyfirmslikeibmorgoogletotheareasofmarketdataandinfrastructure'}
# {'doc_id': 790, 'IDF_scores': 6.75110146893676, 'key': '3whatareprerequisitesforregulatorybuyintonewbusinessmodelsarounddisruptivetechnologies'}
# {'doc_id': 791, 'IDF_scores': 5.36480710781687, 'key': 'sources7'}
# {'doc_id': 792, 'IDF_scores': 6.75110146893676, 'key': 'forbes8'}
# {'doc_id': 793, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 794, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 795, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 796, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 797, 'IDF_scores': 6.75110146893676, 'key': 'in2015bondcubeanelectronicfixedincometradingsystemthathadjustreceivedregulatoryapprovaltotradeineuropefiledforliquidation'}
# {'doc_id': 798, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 799, 'IDF_scores': 6.75110146893676, 'key': '2willthetrendtowardspartnershipsleadtofurtherconsolidationintheplatformuniverse'}
# {'doc_id': 800, 'IDF_scores': 6.75110146893676, 'key': '3canamonolineproductofferingbeasustainablebusinessmodelforplatformsatall'}
# {'doc_id': 801, 'IDF_scores': 5.14166355650266, 'key': 'sources10'}
# {'doc_id': 802, 'IDF_scores': 6.75110146893676, 'key': 'algomi11'}
# {'doc_id': 803, 'IDF_scores': 6.75110146893676, 'key': 'bloomberg12'}
# {'doc_id': 804, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 805, 'IDF_scores': 6.75110146893676, 'key': 'traditionalotcproductsarebecomingmoreandmoreelectronifiedbutarehinderedintheireffortstoscaleupduetofragmentedregulatoryandtechnologicalenvironments'}
# {'doc_id': 806, 'IDF_scores': 6.75110146893676, 'key': 'inordertoscaleupandgarnersuccessjointventuresandpartnershipsbetweenfintechsandincumbentsarekey'}
# {'doc_id': 807, 'IDF_scores': 6.75110146893676, 'key': 'throughthesefindingsthefollowingkeyuncertaintiesaroundthefutureofmarketinfrastructureemerged2uncertaintieswhatwillpoliticaldisruptionandpotentialderegulationmeanforplatformtradingandproliferation'}
# {'doc_id': 808, 'IDF_scores': 6.75110146893676, 'key': 'howwillbuysideinvestordemandforinnovationandnewbusinessmodelsshapetheplatformuniverse'}
# {'doc_id': 809, 'IDF_scores': 6.75110146893676, 'key': 'howfarawayaredisruptivetechnologiessuchasaianddltfromapplicabilityandscalabilityinaproductionenvironment'}
# {'doc_id': 810, 'IDF_scores': 6.75110146893676, 'key': 'whatwilldrivethenecessarycooperationtoembednewbusinessmodelsintotheexistingecosystem'}
# {'doc_id': 811, 'IDF_scores': 6.75110146893676, 'key': 'howwilldisruptivetechnologiesaffectthevaluechainandindividualrolesinmarketinfrastructure'}
# {'doc_id': 812, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 813, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 814, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 815, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 816, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 817, 'IDF_scores': 6.75110146893676, 'key': '...'}
# {'doc_id': 818, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 819, 'IDF_scores': 6.75110146893676, 'key': ''}
# {'doc_id': 820, 'IDF_scores': 6.75110146893676, 'key': 'forwardlookingfirmswillseektopositionthemselvesinareasthatwillcontinuetoaddvalueincludingareascurrentlyoccupiedbyotherfirmsintroductionfindingsuncertaintiesendstatesconclusion187marketinfrastructurereferencesreferences1'}
# {'doc_id': 821, 'IDF_scores': 4.671659927256925, 'key': '2'}
# {'doc_id': 822, 'IDF_scores': 4.553876891600541, 'key': '3'}
# {'doc_id': 823, 'IDF_scores': 4.805191319881447, 'key': '4'}
# {'doc_id': 824, 'IDF_scores': 4.959341999708705, 'key': '5'}
# {'doc_id': 825, 'IDF_scores': 4.805191319881447, 'key': '6'}
# {'doc_id': 826, 'IDF_scores': 4.805191319881447, 'key': '7'}
# {'doc_id': 827, 'IDF_scores': 4.959341999708705, 'key': '8'}
# {'doc_id': 828, 'IDF_scores': 5.14166355650266, 'key': '9'}
# {'doc_id': 829, 'IDF_scores': 6.75110146893676, 'key': 'deutschebörsebuysintosorosbackedbondtradingplatform'}
# {'doc_id': 830, 'IDF_scores': 6.0579542883768145, 'key': 'financialtimes'}
# {'doc_id': 831, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwftcomcontentd32a786a635a11e788140ac7eb84e5f1mhq5je2bestfixedincometradingplatform'}
# {'doc_id': 832, 'IDF_scores': 6.75110146893676, 'key': 'financialnews'}
# {'doc_id': 833, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpttefneventscomshortlistbestfixedincometradingplatformelectronictradinginfixedincomemarkets'}
# {'doc_id': 834, 'IDF_scores': 6.75110146893676, 'key': 'bankforinternationalsettlementsbis'}
# {'doc_id': 835, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwbisorgpublmktc07pdfcftcanewdirectionforward'}
# {'doc_id': 836, 'IDF_scores': 6.75110146893676, 'key': 'uscommodityfuturestradingcommission'}
# {'doc_id': 837, 'IDF_scores': 6.75110146893676, 'key': 'remarksofactingchairmanjchristophergiancarlobeforethe42ndannualinternationalfuturesindustryconferenceinbocaratonfloridausa'}
# {'doc_id': 838, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwcftcgovpressroomspeechestestimonyopagiancarlo20euregulatorsconsidermifidelectronictradinglockout'}
# {'doc_id': 839, 'IDF_scores': 6.75110146893676, 'key': 'risknet'}
# {'doc_id': 840, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwrisknetregulationmifid4778566euregulatorsconsidermifidelectronictradinglockoutsecdisclosuretrendsrelatedtobrexitandthetrumpadministration'}
# {'doc_id': 841, 'IDF_scores': 6.75110146893676, 'key': 'skaddenarpsslatemeagherflomllppublishedonlexologycom'}
# {'doc_id': 842, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwlexologycomlibrarydetailaspxg3573f703ddec483fa53d9cba0201634fdtccpartnerswithibmstartupsforblockchainbasedcreditdefaultswapssolution'}
# {'doc_id': 843, 'IDF_scores': 4.805191319881447, 'key': 'forbes'}
# {'doc_id': 844, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwforbescomsiteslaurashin20170109dtccselectspartnersforblockchainsolutionforcreditdefaultswaps28c877395061thomsonreutersreleasesblockoneiqintoblockchaindevelopercommunity'}
# {'doc_id': 845, 'IDF_scores': 6.75110146893676, 'key': 'thomsonreuters'}
# {'doc_id': 846, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwthomsonreuterscomenpressreleases2017junethomsonreutersreleasesblockoneiqintoblockchaindevelopercommunityhtmltheresanewhotbuttonissueonwallstreetandbattlelinesarebeingdrawn'}
# {'doc_id': 847, 'IDF_scores': 5.36480710781687, 'key': 'businessinsider'}
# {'doc_id': 848, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwbusinessinsidercomstockexchangesmarketdatacostbecomingbigissue20161010'}
# {'doc_id': 849, 'IDF_scores': 6.75110146893676, 'key': 'euronextinvestsinalgomiandexpandsjv'}
# {'doc_id': 850, 'IDF_scores': 6.75110146893676, 'key': 'algomi'}
# {'doc_id': 851, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpwwwalgomicomcompanynewseuronextinvestsinalgomiandexpandsjv111'}
# {'doc_id': 852, 'IDF_scores': 6.75110146893676, 'key': 'auctionbackupsandboringregulation'}
# {'doc_id': 853, 'IDF_scores': 6.0579542883768145, 'key': 'bloomberg'}
# {'doc_id': 854, 'IDF_scores': 6.75110146893676, 'key': 'retrievedfromhttpswwwbloombergcomviewarticles20150723auctionbackupsandboringregulation12'}
# {'doc_id': 855, 'IDF_scores': 6.75110146893676, 'key': '...ö...örghessenmü...öó...'}
